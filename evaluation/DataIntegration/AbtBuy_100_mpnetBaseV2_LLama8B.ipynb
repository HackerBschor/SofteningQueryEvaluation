# %% [markdown]
# # Evaluation of Data Integration
#
# In this notebook, we evaluate how effective two relations can be integrated using the soft join operator.
# Therefore, we utilize the [Datasets for DeepMatcher paper](https://github.com/anhaidgroup/deepmatcher/blob/master/Datasets.md).
#
# The datasets contain two relations with the same entities from two different sources.
# E.g. `iTunes-Amazon` contains song records obtained from iTunes and Amazon. So, the task is to identify same songs.
#
# To test different Models, datasets, ..., there are parameters in the [modifications](#modifications) section.
# **Modfy Code in [Modifications](#modifications) Section Only!**
#
# We calculate:
# * $ TP = \text{True Matches} \cap \text{Predicted Matches} $
# * $ FN = \text{True Matches} \setminus \text{Predicted Matches} $
# * $ FP = \text{Predicted Matches} \setminus \text{True Matches} $
#
# To determine the scores:
# * $ Precision = \frac{TP}{TP + FP}$
# * $ Recall = \frac{TP}{TP + FN}$
# * $ F_1 = \frac{2 \cdot precision \cdot recall}{precision + recall} $
# * BLEU 1-4
#
# ## Imports

# %%
# %%capture
# !rm -rf SofteningQueryEvaluation
# !git clone https://github.com/HackerBschor/SofteningQueryEvaluation
# %cd SofteningQueryEvaluation

# !pip3 install faiss-gpu-cu12

# !pip3 install pgvector

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import time
import json
import tqdm
import pandas as pd


from db.operators import Dummy, InnerSoftJoin

from models import ModelMgr
from models.embedding.SentenceTransformer import SentenceTransformerEmbeddingModel
from models.semantic_validation import LLaMAValidationModel

from evaluation.util import calculate_metrics, calc_bleu
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
with open("evaluation/DataIntegration/DataIntegration.json") as f:
    datasets = json.load(f)

print(", ".join(datasets.keys()))
# Out:
# AbtBuy, AmazonGoogle, Beer, iTunesAmazon, DBLP_ACM, DBLP_SCHOLAR, FodorsZagat, WalmartAmazon

# %% [markdown]
# ## Modifications

# %%
dataset_name = "AbtBuy" # The tested dataset
number_matches = 100

significant_columns_left = ["name", "description", "price"]
significant_columns_right = ["name", "description", "price"]

# %%
# Models
# meta-llama/Llama-3.2-3B-Instruct
# meta-llama/Meta-Llama-3-8B-Instruct
stem = SentenceTransformerEmbeddingModel(ModelMgr())
lsv = LLaMAValidationModel(ModelMgr(), model_path="meta-llama/Meta-Llama-3-8B-Instruct")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]

# %% [markdown]
# ## Function and Dataset Declarations

# %%
significant_columns_left = [f"left_{x}" for x in significant_columns_left]
significant_columns_right = [f"right_{x}" for x in significant_columns_right]

# %%
dataset = datasets[dataset_name]
matches = pd.DataFrame(dataset["matches"])

if number_matches is not None:
    matches = matches.sample(number_matches, random_state=42)

print(len(matches))

matches.head(2)
# Out:
# 100
#      idAbt      idBuy
# 44   22101  201953039
# 568  34548  207907555

# %%
left = pd.DataFrame(dataset["left"])
left.rename(columns={c: f"left_{c}" for c in left.columns}, inplace=True)

if number_matches is not None:
    left = left[left["left_" + matches.columns[0]].isin(matches[matches.columns[0]])]

print(len(left))

left.head(2)
# Out:
# 100
#     left_idAbt                                         left_name  \
# 10       38474  Linksys Gigabit 5-Port Workgroup Switch - EG005W
# 31       20453                Canon Cyan Ink Tank - Cyan - CLI8C
#
#                                      left_description left_price
# 10  Linksys Gigabit 5-Port Workgroup Switch - EG00...     $64.00
# 31  Canon Cyan Ink Tank - CLI8C/ Compatible With T...     $16.00

# %%
right = pd.DataFrame(dataset["right"])
right.rename(columns={c: f"right_{c}" for c in right.columns}, inplace=True)

if number_matches is not None:
    right = right[right["right_" + matches.columns[1]].isin(matches[matches.columns[1]])]

print(len(right))

right.head(2)
# Out:
# 100
#     right_idBuy                                      right_name  \
# 10     10343605  Linksys Instant Gigabit EG005W Ethernet Switch
# 31    201692677           Canon CLI-8C Ink Cartridge - 0621B002
#
#                                  right_description right_manufacturer  \
# 10  Linksys EG005W Gigabit 5-Port Workgroup Switch            LINKSYS
# 31                                            Cyan              Canon
#
#    right_price
# 10        None
# 31      $13.99

# %%
candidates = matches\
    .merge(left, left_on=matches.columns[0], right_on=f"left_{matches.columns[0]}")\
    .merge(right, left_on=matches.columns[1], right_on=f"right_{matches.columns[1]}")\
    .drop(columns=matches.columns)

print(len(candidates))

candidates.head(2)
# Out:
# 100
#    left_idAbt                                       left_name  \
# 0       22101                Canon Photo Ink Cartridge - CL52
# 1       34548  Sony White Earbud Style Headphones - MDREX55WH
#
#                                     left_description left_price  right_idBuy  \
# 0  Canon Photo Ink Cartridge - CL52/ Compatible W...     $25.00    201953039
# 1  Sony MDREX55WHI White Earbud Style Headphones ...       None    207907555
#
#                                           right_name right_description  \
# 0  Canon CL-52 Photo Ink Cartridge For PIXMA iP62...             Color
# 1               Ex Series Earbuds Wht - MDR EX55/WHI              None
#
#   right_manufacturer right_price
# 0              Canon      $18.16
# 1               Sony      $25.76

# %%
gt = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for _, x in candidates.iterrows()}
print(str(gt)[0:100] + "...")
# Out:
# {(34962, 208114681), (38173, 210441817), (33150, 208105630), (38400, 209208547), (14563, 202870448),...

# %% [markdown]
# ### Execute Operator and Evaluate

# %%
def evaluate(em, sv, threshold, method, embedding_comparison, embedding_method):
    key = (threshold, method, embedding_comparison, embedding_method)

    op1 = Dummy("ltable", left.columns, list(left.values))
    op2 = Dummy("rtable", right.columns, list(right.values))

    op = InnerSoftJoin(
        op1, op2, em=em, sv=sv,
        threshold=threshold, method=method,
        columns_left=significant_columns_left, columns_right=significant_columns_right,
        embedding_comparison=embedding_comparison,
        embedding_method = embedding_method,
        zs_system_prompt = 'You are an object-matcher. Check if the two tuples A and B refere to the same real worl entity. If so, answer with "yes", if not, answer with"no" only',
        zs_template = "A is {a}\nB is {b}"
    )

    tic = time.time()
    result = op.open().fetch_all()
    toc = time.time()
    pred = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for x in result}

    scores = calculate_metrics(gt, pred, toc - tic)

    print(key, scores["F1 Score"])

    return key, scores

# %% [markdown]
# ## Evaluation

# %%
thresholds = [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

evaluation_results = {}

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "threshold", embedding_comparison = "RECORD_WISE", embedding_method = "FIELD_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.9, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.8, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.7, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.6, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.5, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.07547169811320754
# (0.4, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.38613861386138615
# (0.3, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.14058577405857742
# (0.2, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.04193751310547285

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "threshold", embedding_comparison = "RECORD_WISE", embedding_method = "FULL_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0
# (0.9, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0.366412213740458
# (0.8, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0.5220125786163522
# (0.7, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0.29464285714285715
# (0.6, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0.09713453132588634

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "threshold", embedding_comparison = "COLUMN_WISE", embedding_method = None)
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'threshold', 'COLUMN_WISE', None) 0
# (0.9, 'threshold', 'COLUMN_WISE', None) 0
# (0.8, 'threshold', 'COLUMN_WISE', None) 0.16071428571428573
# (0.7, 'threshold', 'COLUMN_WISE', None) 0.29411764705882354
# (0.6, 'threshold', 'COLUMN_WISE', None) 0.39826839826839827
# (0.5, 'threshold', 'COLUMN_WISE', None) 0.20625
# (0.4, 'threshold', 'COLUMN_WISE', None) 0.06158583525789068
# (0.3, 'threshold', 'COLUMN_WISE', None) 0.0420781451266638
# (0.2, 'threshold', 'COLUMN_WISE', None) 0.03124023742580443

# %%
res = evaluate(stem, lsv, method = "zero-shot-prompting", threshold = None, embedding_comparison = "RECORD_WISE", embedding_method = None)
evaluation_results[res[0]] = res[1]
# Out:
# (None, 'zero-shot-prompting', 'RECORD_WISE', None) 0.93

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "RECORD_WISE", embedding_method = "FIELD_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.9, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.8, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.7, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.6, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.5, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.07692307692307693
# (0.4, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.5285714285714286
# (0.3, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.8478260869565217
# (0.2, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.93
# (0.1, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.93

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "RECORD_WISE", embedding_method = "FULL_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0
# (0.9, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.384
# (0.8, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.858695652173913
# (0.7, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.93
# (0.6, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.93
# (0.5, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.93
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-5aaae48b5a07> in <cell line: 0>()
#       1 for t in thresholds:
# ----> 2     res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "RECORD_WISE", embedding_method = "FULL_SERIALIZED")
#       3     evaluation_results[res[0]] = res[1]
#       4     if res[1]["Recall"] == 1.0:
#       5         break
#
# <ipython-input-13-f05ceccab72c> in evaluate(em, sv, threshold, method, embedding_comparison, embedding_method)
#      16
#      17     tic = time.time()
# ---> 18     result = op.open().fetch_all()
#      19     toc = time.time()
#      20     pred = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for x in result}
#
# /content/SofteningQueryEvaluation/db/operators/Operator.py in fetch_all(self)
#      43
#      44     def fetch_all(self): # Interface for user to retrieve all records
# ---> 45         return list(self)
#      46
#      47     def fetch_one(self): # Interface for user to retrieve next record
#
# /content/SofteningQueryEvaluation/db/operators/Join.py in __next__(self)
#     472
#     473                     # entity matching not passing -> continue with next left record
# --> 474                     if not self.sv(prompt, system_prompt=self.zs_system_prompt):
#     475                         logging.debug(f"Prompt: \"{prompt}\" filed in semantic validation")
#     476                         continue
#
# /content/SofteningQueryEvaluation/models/semantic_validation/LLaMA.py in __call__(self, prompt, system_prompt)
#      56             attention_mask = attention_mask.cuda()
#      57
# ---> 58         answer_tok = self._model.generate(prompt_tok, attention_mask = attention_mask, **self.generation_config)
#      59         answer = self._tokenizer.decode( answer_tok[0][len(prompt_tok[0]):], skip_special_tokens=True ).lower()
#      60
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2253
#    2254             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2255             result = self._sample(
#    2256                 input_ids,
#    2257                 logits_processor=prepared_logits_processor,
#
# KeyboardInterrupt:

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "COLUMN_WISE", embedding_method = None)
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'both', 'COLUMN_WISE', None) 0
# (0.9, 'both', 'COLUMN_WISE', None) 0
# (0.8, 'both', 'COLUMN_WISE', None) 0.16513761467889906
# (0.7, 'both', 'COLUMN_WISE', None) 0.319327731092437
# (0.6, 'both', 'COLUMN_WISE', None) 0.593103448275862
# (0.5, 'both', 'COLUMN_WISE', None) 0.7349397590361445
# (0.4, 'both', 'COLUMN_WISE', None) 0.8268156424581006
# (0.3, 'both', 'COLUMN_WISE', None) 0.9191919191919193
# (0.2, 'both', 'COLUMN_WISE', None) 0.93
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-97b6a3f82786> in <cell line: 0>()
#       1 for t in thresholds:
# ----> 2     res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "COLUMN_WISE", embedding_method = None)
#       3     evaluation_results[res[0]] = res[1]
#       4     if res[1]["Recall"] == 1.0:
#       5         break
#
# <ipython-input-13-f05ceccab72c> in evaluate(em, sv, threshold, method, embedding_comparison, embedding_method)
#      16
#      17     tic = time.time()
# ---> 18     result = op.open().fetch_all()
#      19     toc = time.time()
#      20     pred = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for x in result}
#
# /content/SofteningQueryEvaluation/db/operators/Operator.py in fetch_all(self)
#      43
#      44     def fetch_all(self): # Interface for user to retrieve all records
# ---> 45         return list(self)
#      46
#      47     def fetch_one(self): # Interface for user to retrieve next record
#
# /content/SofteningQueryEvaluation/db/operators/Join.py in __next__(self)
#     472
#     473                     # entity matching not passing -> continue with next left record
# --> 474                     if not self.sv(prompt, system_prompt=self.zs_system_prompt):
#     475                         logging.debug(f"Prompt: \"{prompt}\" filed in semantic validation")
#     476                         continue
#
# /content/SofteningQueryEvaluation/models/semantic_validation/LLaMA.py in __call__(self, prompt, system_prompt)
#      56             attention_mask = attention_mask.cuda()
#      57
# ---> 58         answer_tok = self._model.generate(prompt_tok, attention_mask = attention_mask, **self.generation_config)
#      59         answer = self._tokenizer.decode( answer_tok[0][len(prompt_tok[0]):], skip_special_tokens=True ).lower()
#      60
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2253
#    2254             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2255             result = self._sample(
#    2256                 input_ids,
#    2257                 logits_processor=prepared_logits_processor,
#
# KeyboardInterrupt:

# %%
gt_blue = {tuple(row[col] for col in list(left.columns) + list(right.columns)) for _, row in candidates.iterrows()}

for key in tqdm.tqdm(evaluation_results):
    result = pd.DataFrame(evaluation_results[key]["pred"], columns=["l", "r"])\
        .merge(left, left_on="l", right_on="left_idAbt")\
        .merge(right, left_on="r", right_on="right_idBuy")

    pred_blue = {tuple(row[col] for col in list(left.columns) + list(right.columns)) for _, row in result.iterrows()}
    scores_bleu = calc_bleu(gt_blue, pred_blue)
    for score_bleu in scores_bleu:
        evaluation_results[key][score_bleu] = scores_bleu[score_bleu]
# Out:
# 100%|██████████| 49/49 [26:11<00:00, 32.07s/it]

# %%
keys = ["threshold", "method", "embedding_comparison", "embedding_method"]
evaluation_results_list = [v | {ki: vi for ki, vi in zip(keys, k)} for k, v in evaluation_results.items()]
df_evaluation_results = pd.DataFrame.from_records(evaluation_results_list, index=keys)
df_evaluation_results
# Out:
#                                                                      Precision  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED   0.666667
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED   0.382353
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED   0.076712
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED   0.021418
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED    0.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED    0.774194
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED    0.380734
# 0.7       threshold           RECORD_WISE          FULL_SERIALIZED    0.173077
# 0.6       threshold           RECORD_WISE          FULL_SERIALIZED    0.051046
# 1.0       threshold           COLUMN_WISE          NaN                0.000000
# 0.9       threshold           COLUMN_WISE          NaN                0.000000
# 0.8       threshold           COLUMN_WISE          NaN                0.750000
# 0.7       threshold           COLUMN_WISE          NaN                0.555556
# 0.6       threshold           COLUMN_WISE          NaN                0.351145
# 0.5       threshold           COLUMN_WISE          NaN                0.122222
# 0.4       threshold           COLUMN_WISE          NaN                0.032026
# 0.3       threshold           COLUMN_WISE          NaN                0.021501
# 0.2       threshold           COLUMN_WISE          NaN                0.015868
# NaN       zero-shot-prompting RECORD_WISE          NaN                0.930000
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED   1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED   0.925000
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED   0.928571
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED   0.930000
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED   0.930000
# 1.0       both                RECORD_WISE          FULL_SERIALIZED    0.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED    0.960000
# 0.8       both                RECORD_WISE          FULL_SERIALIZED    0.940476
# 0.7       both                RECORD_WISE          FULL_SERIALIZED    0.930000
# 0.6       both                RECORD_WISE          FULL_SERIALIZED    0.930000
# 0.5       both                RECORD_WISE          FULL_SERIALIZED    0.930000
# 1.0       both                COLUMN_WISE          NaN                0.000000
# 0.9       both                COLUMN_WISE          NaN                0.000000
# 0.8       both                COLUMN_WISE          NaN                1.000000
# 0.7       both                COLUMN_WISE          NaN                1.000000
# 0.6       both                COLUMN_WISE          NaN                0.955556
# 0.5       both                COLUMN_WISE          NaN                0.924242
# 0.4       both                COLUMN_WISE          NaN                0.936709
# 0.3       both                COLUMN_WISE          NaN                0.928571
# 0.2       both                COLUMN_WISE          NaN                0.930000
#
#                                                                      Recall  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED    0.00
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED    0.00
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED    0.00
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED    0.00
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED    0.00
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED    0.04
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED    0.39
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED    0.84
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED    1.00
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED     0.00
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED     0.24
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED     0.83
# 0.7       threshold           RECORD_WISE          FULL_SERIALIZED     0.99
# 0.6       threshold           RECORD_WISE          FULL_SERIALIZED     1.00
# 1.0       threshold           COLUMN_WISE          NaN                 0.00
# 0.9       threshold           COLUMN_WISE          NaN                 0.00
# 0.8       threshold           COLUMN_WISE          NaN                 0.09
# 0.7       threshold           COLUMN_WISE          NaN                 0.20
# 0.6       threshold           COLUMN_WISE          NaN                 0.46
# 0.5       threshold           COLUMN_WISE          NaN                 0.66
# 0.4       threshold           COLUMN_WISE          NaN                 0.80
# 0.3       threshold           COLUMN_WISE          NaN                 0.98
# 0.2       threshold           COLUMN_WISE          NaN                 1.00
# NaN       zero-shot-prompting RECORD_WISE          NaN                 0.93
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED    0.00
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED    0.00
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED    0.00
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED    0.00
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED    0.00
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED    0.04
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED    0.37
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED    0.78
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED    0.93
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED    0.93
# 1.0       both                RECORD_WISE          FULL_SERIALIZED     0.00
# 0.9       both                RECORD_WISE          FULL_SERIALIZED     0.24
# 0.8       both                RECORD_WISE          FULL_SERIALIZED     0.79
# 0.7       both                RECORD_WISE          FULL_SERIALIZED     0.93
# 0.6       both                RECORD_WISE          FULL_SERIALIZED     0.93
# 0.5       both                RECORD_WISE          FULL_SERIALIZED     0.93
# 1.0       both                COLUMN_WISE          NaN                 0.00
# 0.9       both                COLUMN_WISE          NaN                 0.00
# 0.8       both                COLUMN_WISE          NaN                 0.09
# 0.7       both                COLUMN_WISE          NaN                 0.19
# 0.6       both                COLUMN_WISE          NaN                 0.43
# 0.5       both                COLUMN_WISE          NaN                 0.61
# 0.4       both                COLUMN_WISE          NaN                 0.74
# 0.3       both                COLUMN_WISE          NaN                 0.91
# 0.2       both                COLUMN_WISE          NaN                 0.93
#
#                                                                      F1 Score  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED  0.075472
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.386139
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.140586
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  0.041938
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.366412
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   0.522013
# 0.7       threshold           RECORD_WISE          FULL_SERIALIZED   0.294643
# 0.6       threshold           RECORD_WISE          FULL_SERIALIZED   0.097135
# 1.0       threshold           COLUMN_WISE          NaN               0.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.000000
# 0.8       threshold           COLUMN_WISE          NaN               0.160714
# 0.7       threshold           COLUMN_WISE          NaN               0.294118
# 0.6       threshold           COLUMN_WISE          NaN               0.398268
# 0.5       threshold           COLUMN_WISE          NaN               0.206250
# 0.4       threshold           COLUMN_WISE          NaN               0.061586
# 0.3       threshold           COLUMN_WISE          NaN               0.042078
# 0.2       threshold           COLUMN_WISE          NaN               0.031240
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.930000
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED  0.076923
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.528571
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.847826
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.930000
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.930000
# 1.0       both                RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.384000
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.858696
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.930000
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.930000
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.930000
# 1.0       both                COLUMN_WISE          NaN               0.000000
# 0.9       both                COLUMN_WISE          NaN               0.000000
# 0.8       both                COLUMN_WISE          NaN               0.165138
# 0.7       both                COLUMN_WISE          NaN               0.319328
# 0.6       both                COLUMN_WISE          NaN               0.593103
# 0.5       both                COLUMN_WISE          NaN               0.734940
# 0.4       both                COLUMN_WISE          NaN               0.826816
# 0.3       both                COLUMN_WISE          NaN               0.919192
# 0.2       both                COLUMN_WISE          NaN               0.930000
#
#                                                                       tp   fn  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED    0  100
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED    0  100
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED    0  100
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED    0  100
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED    0  100
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED    4   96
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED   39   61
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED   84   16
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  100    0
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED     0  100
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED    24   76
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED    83   17
# 0.7       threshold           RECORD_WISE          FULL_SERIALIZED    99    1
# 0.6       threshold           RECORD_WISE          FULL_SERIALIZED   100    0
# 1.0       threshold           COLUMN_WISE          NaN                 0  100
# 0.9       threshold           COLUMN_WISE          NaN                 0  100
# 0.8       threshold           COLUMN_WISE          NaN                 9   91
# 0.7       threshold           COLUMN_WISE          NaN                20   80
# 0.6       threshold           COLUMN_WISE          NaN                46   54
# 0.5       threshold           COLUMN_WISE          NaN                66   34
# 0.4       threshold           COLUMN_WISE          NaN                80   20
# 0.3       threshold           COLUMN_WISE          NaN                98    2
# 0.2       threshold           COLUMN_WISE          NaN               100    0
# NaN       zero-shot-prompting RECORD_WISE          NaN                93    7
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED    0  100
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED    0  100
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED    0  100
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED    0  100
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED    0  100
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED    4   96
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED   37   63
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED   78   22
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED   93    7
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED   93    7
# 1.0       both                RECORD_WISE          FULL_SERIALIZED     0  100
# 0.9       both                RECORD_WISE          FULL_SERIALIZED    24   76
# 0.8       both                RECORD_WISE          FULL_SERIALIZED    79   21
# 0.7       both                RECORD_WISE          FULL_SERIALIZED    93    7
# 0.6       both                RECORD_WISE          FULL_SERIALIZED    93    7
# 0.5       both                RECORD_WISE          FULL_SERIALIZED    93    7
# 1.0       both                COLUMN_WISE          NaN                 0  100
# 0.9       both                COLUMN_WISE          NaN                 0  100
# 0.8       both                COLUMN_WISE          NaN                 9   91
# 0.7       both                COLUMN_WISE          NaN                19   81
# 0.6       both                COLUMN_WISE          NaN                43   57
# 0.5       both                COLUMN_WISE          NaN                61   39
# 0.4       both                COLUMN_WISE          NaN                74   26
# 0.3       both                COLUMN_WISE          NaN                91    9
# 0.2       both                COLUMN_WISE          NaN                93    7
#
#                                                                        fp  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED     0
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED     0
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED     0
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED     0
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED     0
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED     2
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED    63
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  1011
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  4569
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED      0
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED      7
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED    135
# 0.7       threshold           RECORD_WISE          FULL_SERIALIZED    473
# 0.6       threshold           RECORD_WISE          FULL_SERIALIZED   1859
# 1.0       threshold           COLUMN_WISE          NaN                  0
# 0.9       threshold           COLUMN_WISE          NaN                  0
# 0.8       threshold           COLUMN_WISE          NaN                  3
# 0.7       threshold           COLUMN_WISE          NaN                 16
# 0.6       threshold           COLUMN_WISE          NaN                 85
# 0.5       threshold           COLUMN_WISE          NaN                474
# 0.4       threshold           COLUMN_WISE          NaN               2418
# 0.3       threshold           COLUMN_WISE          NaN               4460
# 0.2       threshold           COLUMN_WISE          NaN               6202
# NaN       zero-shot-prompting RECORD_WISE          NaN                  7
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED     0
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED     0
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED     0
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED     0
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED     0
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED     0
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED     3
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED     6
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED     7
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED     7
# 1.0       both                RECORD_WISE          FULL_SERIALIZED      0
# 0.9       both                RECORD_WISE          FULL_SERIALIZED      1
# 0.8       both                RECORD_WISE          FULL_SERIALIZED      5
# 0.7       both                RECORD_WISE          FULL_SERIALIZED      7
# 0.6       both                RECORD_WISE          FULL_SERIALIZED      7
# 0.5       both                RECORD_WISE          FULL_SERIALIZED      7
# 1.0       both                COLUMN_WISE          NaN                  0
# 0.9       both                COLUMN_WISE          NaN                  0
# 0.8       both                COLUMN_WISE          NaN                  0
# 0.7       both                COLUMN_WISE          NaN                  0
# 0.6       both                COLUMN_WISE          NaN                  2
# 0.5       both                COLUMN_WISE          NaN                  5
# 0.4       both                COLUMN_WISE          NaN                  5
# 0.3       both                COLUMN_WISE          NaN                  7
# 0.2       both                COLUMN_WISE          NaN                  7
#
#                                                                          runtime  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED     2.926863
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED     1.948756
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED     1.892203
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED     1.905328
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED     1.900344
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED     1.950623
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED     1.963640
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED     1.939040
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED     1.941306
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED      1.700940
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED      1.670855
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED      1.660608
# 0.7       threshold           RECORD_WISE          FULL_SERIALIZED      1.672556
# 0.6       threshold           RECORD_WISE          FULL_SERIALIZED      1.710177
# 1.0       threshold           COLUMN_WISE          NaN                  2.056543
# 0.9       threshold           COLUMN_WISE          NaN                  2.164632
# 0.8       threshold           COLUMN_WISE          NaN                  2.192292
# 0.7       threshold           COLUMN_WISE          NaN                  2.204728
# 0.6       threshold           COLUMN_WISE          NaN                  2.314921
# 0.5       threshold           COLUMN_WISE          NaN                  2.320885
# 0.4       threshold           COLUMN_WISE          NaN                  2.320258
# 0.3       threshold           COLUMN_WISE          NaN                  2.369694
# 0.2       threshold           COLUMN_WISE          NaN                  2.475631
# NaN       zero-shot-prompting RECORD_WISE          NaN               1023.722756
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED     1.975326
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED     1.961034
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED     1.931176
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED     1.927994
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED     1.961316
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED     2.600758
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED    12.598811
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED   114.226714
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED   480.351518
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED   944.988542
# 1.0       both                RECORD_WISE          FULL_SERIALIZED      1.744074
# 0.9       both                RECORD_WISE          FULL_SERIALIZED      4.977062
# 0.8       both                RECORD_WISE          FULL_SERIALIZED     24.287283
# 0.7       both                RECORD_WISE          FULL_SERIALIZED     60.508051
# 0.6       both                RECORD_WISE          FULL_SERIALIZED    202.799008
# 0.5       both                RECORD_WISE          FULL_SERIALIZED    593.579252
# 1.0       both                COLUMN_WISE          NaN                  2.126851
# 0.9       both                COLUMN_WISE          NaN                  2.281256
# 0.8       both                COLUMN_WISE          NaN                  3.561336
# 0.7       both                COLUMN_WISE          NaN                  6.106469
# 0.6       both                COLUMN_WISE          NaN                 16.038518
# 0.5       both                COLUMN_WISE          NaN                 58.513942
# 0.4       both                COLUMN_WISE          NaN                256.944685
# 0.3       both                COLUMN_WISE          NaN                467.298110
# 0.2       both                COLUMN_WISE          NaN                648.176663
#
#                                                                                                                   pred  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED  {(38400, 209208547), (14563, 202870448), (2898...
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  {(34728, 203142438), (34280, 207391014), (2989...
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  {(34728, 203142438), (34962, 208114681), (3566...
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  {(33326, 208289990), (34962, 208114681), (3367...
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED                                                  {}
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   {(38400, 209208547), (14563, 202870448), (2843...
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   {(34728, 203142438), (38173, 210441817), (3428...
# 0.7       threshold           RECORD_WISE          FULL_SERIALIZED   {(33326, 208289990), (34728, 203142438), (3496...
# 0.6       threshold           RECORD_WISE          FULL_SERIALIZED   {(33326, 208289990), (34962, 208114681), (3343...
# 1.0       threshold           COLUMN_WISE          NaN                                                              {}
# 0.9       threshold           COLUMN_WISE          NaN                                                              {}
# 0.8       threshold           COLUMN_WISE          NaN               {(33508, 206928380), (23965, 203322272), (3840...
# 0.7       threshold           COLUMN_WISE          NaN               {(34728, 203142438), (38400, 209208547), (1456...
# 0.6       threshold           COLUMN_WISE          NaN               {(25905, 207527632), (30808, 203142438), (3472...
# 0.5       threshold           COLUMN_WISE          NaN               {(34728, 203142438), (34962, 208114681), (3315...
# 0.4       threshold           COLUMN_WISE          NaN               {(34962, 208114681), (33438, 209871973), (3349...
# 0.3       threshold           COLUMN_WISE          NaN               {(33326, 208289990), (34962, 208114681), (3349...
# 0.2       threshold           COLUMN_WISE          NaN               {(33490, 206576716), (35334, 205886768), (3365...
# NaN       zero-shot-prompting RECORD_WISE          NaN               {(38173, 210441817), (33150, 208105630), (3840...
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED  {(38400, 209208547), (14563, 202870448), (3607...
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  {(38400, 209208547), (14563, 202870448), (3409...
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  {(38173, 210441817), (33150, 208105630), (3840...
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  {(38173, 210441817), (33150, 208105630), (3840...
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  {(38173, 210441817), (33150, 208105630), (3840...
# 1.0       both                RECORD_WISE          FULL_SERIALIZED                                                  {}
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   {(38400, 209208547), (14563, 202870448), (2843...
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   {(38173, 210441817), (33150, 208105630), (3840...
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   {(38173, 210441817), (33150, 208105630), (3840...
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   {(38173, 210441817), (33150, 208105630), (3840...
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   {(38173, 210441817), (33150, 208105630), (3840...
# 1.0       both                COLUMN_WISE          NaN                                                              {}
# 0.9       both                COLUMN_WISE          NaN                                                              {}
# 0.8       both                COLUMN_WISE          NaN               {(33508, 206928380), (23965, 203322272), (3840...
# 0.7       both                COLUMN_WISE          NaN               {(38400, 209208547), (14563, 202870448), (3820...
# 0.6       both                COLUMN_WISE          NaN               {(33150, 208105630), (38400, 209208547), (1456...
# 0.5       both                COLUMN_WISE          NaN               {(38173, 210441817), (33150, 208105630), (3840...
# 0.4       both                COLUMN_WISE          NaN               {(38173, 210441817), (33150, 208105630), (3840...
# 0.3       both                COLUMN_WISE          NaN               {(38173, 210441817), (33150, 208105630), (3840...
# 0.2       both                COLUMN_WISE          NaN               {(38173, 210441817), (33150, 208105630), (3840...
#
#                                                                         bleu1  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED  0.264302
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.633820
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.476671
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.7       threshold           RECORD_WISE          FULL_SERIALIZED   0.993864
# 0.6       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN              -1.000000
# 0.8       threshold           COLUMN_WISE          NaN               0.338679
# 0.7       threshold           COLUMN_WISE          NaN               0.476654
# 0.6       threshold           COLUMN_WISE          NaN               0.716553
# 0.5       threshold           COLUMN_WISE          NaN               0.894171
# 0.4       threshold           COLUMN_WISE          NaN               0.961041
# 0.3       threshold           COLUMN_WISE          NaN               0.996565
# 0.2       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.954420
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED  0.262294
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.567937
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.852580
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.954420
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.954420
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.470168
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.857796
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.954420
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.954420
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.954420
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN              -1.000000
# 0.8       both                COLUMN_WISE          NaN               0.325717
# 0.7       both                COLUMN_WISE          NaN               0.434045
# 0.6       both                COLUMN_WISE          NaN               0.617457
# 0.5       both                COLUMN_WISE          NaN               0.746034
# 0.4       both                COLUMN_WISE          NaN               0.825981
# 0.3       both                COLUMN_WISE          NaN               0.940519
# 0.2       both                COLUMN_WISE          NaN               0.954420
#
#                                                                         bleu2  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED  0.156949
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.564526
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   0.880966
# 0.7       threshold           RECORD_WISE          FULL_SERIALIZED   0.992681
# 0.6       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN              -1.000000
# 0.8       threshold           COLUMN_WISE          NaN               0.231952
# 0.7       threshold           COLUMN_WISE          NaN               0.382942
# 0.6       threshold           COLUMN_WISE          NaN               0.667036
# 0.5       threshold           COLUMN_WISE          NaN               0.876282
# 0.4       threshold           COLUMN_WISE          NaN               0.954183
# 0.3       threshold           COLUMN_WISE          NaN               0.995703
# 0.2       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.945829
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED  0.153828
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.484812
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.821922
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.945829
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.945829
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.374988
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.830385
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.945829
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.945829
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.945829
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN              -1.000000
# 0.8       both                COLUMN_WISE          NaN               0.217950
# 0.7       both                COLUMN_WISE          NaN               0.330395
# 0.6       both                COLUMN_WISE          NaN               0.542078
# 0.5       both                COLUMN_WISE          NaN               0.695819
# 0.4       both                COLUMN_WISE          NaN               0.793185
# 0.3       both                COLUMN_WISE          NaN               0.929768
# 0.2       both                COLUMN_WISE          NaN               0.945829
#
#                                                                         bleu3  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED  0.112511
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.932777
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.334626
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   0.870036
# 0.7       threshold           RECORD_WISE          FULL_SERIALIZED   0.992277
# 0.6       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN              -1.000000
# 0.8       threshold           COLUMN_WISE          NaN               0.182420
# 0.7       threshold           COLUMN_WISE          NaN               0.339430
# 0.6       threshold           COLUMN_WISE          NaN               0.641864
# 0.5       threshold           COLUMN_WISE          NaN               0.866766
# 0.4       threshold           COLUMN_WISE          NaN               0.950163
# 0.3       threshold           COLUMN_WISE          NaN               0.995203
# 0.2       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.940617
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED  0.108337
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.444995
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.804788
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.940617
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.940617
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.325845
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.815557
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.940617
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.940617
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.940617
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN              -1.000000
# 0.8       both                COLUMN_WISE          NaN               0.167413
# 0.7       both                COLUMN_WISE          NaN               0.280050
# 0.6       both                COLUMN_WISE          NaN               0.503850
# 0.5       both                COLUMN_WISE          NaN               0.668116
# 0.4       both                COLUMN_WISE          NaN               0.774146
# 0.3       both                COLUMN_WISE          NaN               0.923488
# 0.2       both                COLUMN_WISE          NaN               0.940617
#
#                                                                         bleu4
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED  0.086111
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.510723
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.304636
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   0.863739
# 0.7       threshold           RECORD_WISE          FULL_SERIALIZED   0.992217
# 0.6       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN              -1.000000
# 0.8       threshold           COLUMN_WISE          NaN               0.152626
# 0.7       threshold           COLUMN_WISE          NaN               0.313709
# 0.6       threshold           COLUMN_WISE          NaN               0.626041
# 0.5       threshold           COLUMN_WISE          NaN               0.860168
# 0.4       threshold           COLUMN_WISE          NaN               0.947251
# 0.3       threshold           COLUMN_WISE          NaN               0.994906
# 0.2       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.937897
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED  0.081272
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.419298
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.795191
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.937897
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.937897
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.295469
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.806857
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.937897
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.937897
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.937897
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN              -1.000000
# 0.8       both                COLUMN_WISE          NaN               0.137151
# 0.7       both                COLUMN_WISE          NaN               0.248497
# 0.6       both                COLUMN_WISE          NaN               0.479480
# 0.5       both                COLUMN_WISE          NaN               0.649509
# 0.4       both                COLUMN_WISE          NaN               0.761094
# 0.3       both                COLUMN_WISE          NaN               0.920026
# 0.2       both                COLUMN_WISE          NaN               0.937897

# %%
name = "AbtBuy_100_mpnetBaseV2_LLama8B"
df_evaluation_results.drop(columns=["pred"]).to_csv(f"{name}.csv")
df_evaluation_results.to_pickle(f"{name}.pkl")
