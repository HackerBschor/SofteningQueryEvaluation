# %% [markdown]
# # Evaluation of Data Integration
#
# In this notebook, we evaluate how effective two relations can be integrated using the soft join operator.
# Therefore, we utilize the [Datasets for DeepMatcher paper](https://github.com/anhaidgroup/deepmatcher/blob/master/Datasets.md).
#
# The datasets contain two relations with the same entities from two different sources.
# E.g. `iTunes-Amazon` contains song records obtained from iTunes and Amazon. So, the task is to identify same songs.
#
# To test different Models, datasets, ..., there are parameters in the [modifications](#modifications) section.
# **Modfy Code in [Modifications](#modifications) Section Only!**
#
# We calculate:
# * $ TP = \text{True Matches} \cap \text{Predicted Matches} $
# * $ FN = \text{True Matches} \setminus \text{Predicted Matches} $
# * $ FP = \text{Predicted Matches} \setminus \text{True Matches} $
#
# To determine the scores:
# * $ Precision = \frac{TP}{TP + FP}$
# * $ Recall = \frac{TP}{TP + FN}$
# * $ F_1 = \frac{2 \cdot precision \cdot recall}{precision + recall} $
# * BLEU 1-4
#
# ## Imports

# %%
# %%capture
# !rm -rf SofteningQueryEvaluation
# !git clone https://github.com/HackerBschor/SofteningQueryEvaluation
# %cd SofteningQueryEvaluation

# !pip3 install faiss-gpu-cu12
# !pip3 install pgvector

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import time
import json
import tqdm
import pandas as pd


from db.operators import Dummy, InnerSoftJoin

from models import ModelMgr
from models.embedding.SentenceTransformer import SentenceTransformerEmbeddingModel
from models.semantic_validation import LLaMAValidationModel

from evaluation.util import calculate_metrics, calc_bleu

# %%
with open("evaluation/DataIntegration/DataIntegration.json") as f:
    datasets = json.load(f)

print(", ".join(datasets.keys()))
# Out:
# AbtBuy, AmazonGoogle, Beer, iTunesAmazon, DBLP_ACM, DBLP_SCHOLAR, FodorsZagat, WalmartAmazon

# %% [markdown]
# ## Modifications

# %%
dataset_name = "iTunesAmazon" # The tested dataset

significant_columns_left = ["Album_Name", "Artist_Name", "Released", "Song_Name", "Time"]
significant_columns_right = ["Album_Name", "Artist_Name", "Released", "Song_Name", "Time"]

# %%
# Models
stem = SentenceTransformerEmbeddingModel(ModelMgr())
lsv = LLaMAValidationModel(ModelMgr())
# Out:
# config.json:   0%|          | 0.00/878 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %% [markdown]
# ## Function and Dataset Declarations

# %%
significant_columns_left = [f"left_{x}" for x in significant_columns_left]
significant_columns_right = [f"right_{x}" for x in significant_columns_right]

# %%
dataset = datasets[dataset_name]
matches = pd.DataFrame(dataset["matches"])
matches.head(2)
# Out:
#    snoLeft  snoRight
# 0      111     53124
# 1      148     50767

# %%
left = pd.DataFrame(dataset["left"])
left.rename(columns={c: f"left_{c}" for c in left.columns}, inplace=True)
left.head(2)
# Out:
#    left_snoLeft left_Album_Name left_Album_Price left_Artist_Name  \
# 0           111             VHS           $7.99     X Ambassadors
# 1           148  Title (Deluxe)          $12.99    Meghan Trainor
#
#                                       left_CopyRight  left_Customer_Rating  \
# 0               2015 KIDinaKORNER/Interscope Records               4.54839
# 1   2014, 2015 Epic Records, a division of Sony M...               4.06740
#
#                                  left_Genre left_Price left_Released  \
# 0  Alternative,Music,Rock,Adult Alternative     $1.29      30-Jun-15
# 1    Pop,Music,Rock,Pop/Rock,Dance,Teen Pop     $1.29       9-Jan-15
#
#           left_Song_Name left_Time
# 0  VHS Outro (Interlude)      1:25
# 1                 Credit      2:51

# %%
right = pd.DataFrame(dataset["right"])
right.rename(columns={c: f"right_{c}" for c in right.columns}, inplace=True)
right.head(2)
# Out:
#    right_snoRight right_Album_Name right_Artist_Name  \
# 0             363           #NAME?        Ed Sheeran
# 1             379           #NAME?        Ed Sheeran
#
#             right_Song_Name right_Price right_Time      right_Released  \
# 0  Sunburn (Deluxe Edition)       $1.29       4:35   September 9, 2011
# 1  Sunburn (Deluxe Edition)       $1.29       4:35   September 9, 2011
#
#             right_Label right_Copyright right_Genre
# 0   Atlantic Records UK    Doll records         Pop
# 1   Atlantic Records UK    Doll records         Pop

# %%
candidates = matches\
    .merge(left, left_on=matches.columns[0], right_on=f"left_{matches.columns[0]}")\
    .merge(right, left_on=matches.columns[1], right_on=f"right_{matches.columns[1]}")\
    .drop(columns=matches.columns)

candidates.head(2)
# Out:
#    left_snoLeft left_Album_Name left_Album_Price left_Artist_Name  \
# 0           111             VHS           $7.99     X Ambassadors
# 1           148  Title (Deluxe)          $12.99    Meghan Trainor
#
#                                       left_CopyRight  left_Customer_Rating  \
# 0               2015 KIDinaKORNER/Interscope Records               4.54839
# 1   2014, 2015 Epic Records, a division of Sony M...               4.06740
#
#                                  left_Genre left_Price left_Released  \
# 0  Alternative,Music,Rock,Adult Alternative     $1.29      30-Jun-15
# 1    Pop,Music,Rock,Pop/Rock,Dance,Teen Pop     $1.29       9-Jan-15
#
#           left_Song_Name  ... right_snoRight  right_Album_Name  \
# 0  VHS Outro (Interlude)  ...          53124    VHS [Explicit]
# 1                 Credit  ...          50767    Title (Deluxe)
#
#   right_Artist_Name                   right_Song_Name right_Price right_Time  \
# 0     X Ambassadors  VHS Outro (Interlude) [Explicit]       $1.29       1:25
# 1    Meghan Trainor                            Credit       $1.29       2:51
#
#      right_Released                       right_Label  \
# 0     June 30, 2015   KIDinaKORNER/Interscope Records
# 1   January 9, 2015                              Epic
#
#                                      right_Copyright       right_Genre
# 0           (C) 2015 KIDinaKORNER/Interscope Records  Alternative Rock
# 1   2011 What A Music Ltd, licence exclusive Parl...               Pop
#
# [2 rows x 21 columns]

# %%
gt = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for _, x in candidates.iterrows()}
print(str(gt)[0:500] + "...")
# Out:
# {(2743, 17193), (6533, 38335), (5713, 35091), (1490, 3901), (206, 41214), (4748, 5685), (4302, 29727), (3763, 38465), (1165, 28023), (1070, 11280), (2223, 816), (2783, 31567), (1898, 51663), (3772, 38476), (427, 33316), (538, 1879), (250, 53124), (4414, 42138), (3325, 7406), (3422, 34354), (3945, 18982), (4588, 26169), (2480, 33820), (1152, 53319), (593, 43724), (4660, 41125), (3851, 9123), (255, 49141), (3357, 39370), (669, 24650), (3927, 16409), (6048, 4670), (6219, 29615), (1407, 48324), (610...

# %% [markdown]
# ### Execute Operator and Evaluate

# %%
def evaluate(em, sv, threshold, method, embedding_comparison, embedding_method):
    key = (threshold, method, embedding_comparison, embedding_method)

    op1 = Dummy("ltable", left.columns, list(left.values))
    op2 = Dummy("rtable", right.columns, list(right.values))

    op = InnerSoftJoin(
        op1, op2, em=em, sv=sv,
        threshold=threshold, method=method,
        columns_left=significant_columns_left, columns_right=significant_columns_right,
        embedding_comparison=embedding_comparison,
        embedding_method = embedding_method
    )

    tic = time.time()
    result = op.open().fetch_all()
    toc = time.time()
    pred = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for x in result}

    scores = calculate_metrics(gt, pred, toc - tic)

    print(key, scores["F1 Score"])

    return key, scores

# %% [markdown]
# ## Evaluation

# %%
thresholds = [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

evaluation_results = {}

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "threshold", embedding_comparison = "RECORD_WISE", embedding_method = "FIELD_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.9, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.8, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.7, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.6, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.5, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.4, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.015037593984962407
# (0.3, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.7014925373134329
# (0.2, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.023506366307541625

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "threshold", embedding_comparison = "RECORD_WISE", embedding_method = "FULL_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0
# (0.9, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7365269461077845
# (0.8, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0.020618556701030924

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "threshold", embedding_comparison = "COLUMN_WISE", embedding_method = None)
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'threshold', 'COLUMN_WISE', None) 0
# (0.9, 'threshold', 'COLUMN_WISE', None) 0.6176470588235294
# (0.8, 'threshold', 'COLUMN_WISE', None) 0.8683274021352313
# (0.7, 'threshold', 'COLUMN_WISE', None) 0.825

# %%
res = evaluate(stem, lsv, method = "zero-shot-prompting", threshold = None, embedding_comparison = "RECORD_WISE", embedding_method = None)
evaluation_results[res[0]] = res[1]
# Out:
# (None, 'zero-shot-prompting', 'RECORD_WISE', None) 0.7380952380952381

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "RECORD_WISE", embedding_method = "FIELD_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.9, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.8, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.7, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.6, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.5, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.4, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.015037593984962407
# (0.3, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.6160714285714286
# (0.2, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.7380952380952381
# (0.1, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.7380952380952381

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "RECORD_WISE", embedding_method = "FULL_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0
# (0.9, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7338709677419355
# (0.8, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7380952380952381
# (0.7, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7380952380952381
# (0.6, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7380952380952381
# (0.5, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7380952380952381
# (0.4, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7380952380952381
# (0.3, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7380952380952381
# (0.2, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7380952380952381
# (0.1, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7380952380952381

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "COLUMN_WISE", embedding_method = None)
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'both', 'COLUMN_WISE', None) 0
# (0.9, 'both', 'COLUMN_WISE', None) 0.5
# (0.8, 'both', 'COLUMN_WISE', None) 0.7302904564315352
# (0.7, 'both', 'COLUMN_WISE', None) 0.7380952380952381
# (0.6, 'both', 'COLUMN_WISE', None) 0.7380952380952381
# (0.5, 'both', 'COLUMN_WISE', None) 0.7380952380952381
# (0.4, 'both', 'COLUMN_WISE', None) 0.7380952380952381
# (0.3, 'both', 'COLUMN_WISE', None) 0.7380952380952381
# (0.2, 'both', 'COLUMN_WISE', None) 0.7380952380952381
# (0.1, 'both', 'COLUMN_WISE', None) 0.7380952380952381

# %%
gt_blue = {tuple(row[col] for col in list(left.columns) + list(right.columns)) for _, row in candidates.iterrows()}

for key in tqdm.tqdm(evaluation_results):
    result = pd.DataFrame(evaluation_results[key]["pred"], columns=["l", "r"])\
        .merge(left, left_on="l", right_on="left_snoLeft")\
        .merge(right, left_on="r", right_on="right_snoRight")

    pred_blue = {tuple(row[col] for col in list(left.columns) + list(right.columns)) for _, row in result.iterrows()}
    scores_bleu = calc_bleu(gt_blue, pred_blue)
    for score_bleu in scores_bleu:
        evaluation_results[key][score_bleu] = scores_bleu[score_bleu]
# Out:
# 100%|██████████| 47/47 [12:01<00:00, 15.36s/it]

# %%
keys = ["threshold", "method", "embedding_comparison", "embedding_method"]
evaluation_results_list = [v | {ki: vi for ki, vi in zip(keys, k)} for k, v in evaluation_results.items()]
df_evaluation_results = pd.DataFrame.from_records(evaluation_results_list, index=keys)
df_evaluation_results
# Out:
#                                                                      Precision  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED   1.000000
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED   0.691176
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED   0.011893
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED    0.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED    0.608911
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED    0.010417
# 1.0       threshold           COLUMN_WISE          NaN                0.000000
# 0.9       threshold           COLUMN_WISE          NaN                0.875000
# 0.8       threshold           COLUMN_WISE          NaN                0.818792
# 0.7       threshold           COLUMN_WISE          NaN                0.702128
# NaN       zero-shot-prompting RECORD_WISE          NaN                0.775000
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED   1.000000
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED   0.750000
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED   0.775000
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED   0.775000
# 1.0       both                RECORD_WISE          FULL_SERIALIZED    0.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED    0.784483
# 0.8       both                RECORD_WISE          FULL_SERIALIZED    0.775000
# 0.7       both                RECORD_WISE          FULL_SERIALIZED    0.775000
# 0.6       both                RECORD_WISE          FULL_SERIALIZED    0.775000
# 0.5       both                RECORD_WISE          FULL_SERIALIZED    0.775000
# 0.4       both                RECORD_WISE          FULL_SERIALIZED    0.775000
# 0.3       both                RECORD_WISE          FULL_SERIALIZED    0.775000
# 0.2       both                RECORD_WISE          FULL_SERIALIZED    0.775000
# 0.1       both                RECORD_WISE          FULL_SERIALIZED    0.775000
# 1.0       both                COLUMN_WISE          NaN                0.000000
# 0.9       both                COLUMN_WISE          NaN                0.884615
# 0.8       both                COLUMN_WISE          NaN                0.807339
# 0.7       both                COLUMN_WISE          NaN                0.775000
# 0.6       both                COLUMN_WISE          NaN                0.775000
# 0.5       both                COLUMN_WISE          NaN                0.775000
# 0.4       both                COLUMN_WISE          NaN                0.775000
# 0.3       both                COLUMN_WISE          NaN                0.775000
# 0.2       both                COLUMN_WISE          NaN                0.775000
# 0.1       both                COLUMN_WISE          NaN                0.775000
#
#                                                                        Recall  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.007576
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.712121
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.931818
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN               0.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.477273
# 0.8       threshold           COLUMN_WISE          NaN               0.924242
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.704545
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.007576
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.522727
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.704545
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.704545
# 1.0       both                RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.689394
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.704545
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.704545
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.704545
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.704545
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   0.704545
# 0.3       both                RECORD_WISE          FULL_SERIALIZED   0.704545
# 0.2       both                RECORD_WISE          FULL_SERIALIZED   0.704545
# 0.1       both                RECORD_WISE          FULL_SERIALIZED   0.704545
# 1.0       both                COLUMN_WISE          NaN               0.000000
# 0.9       both                COLUMN_WISE          NaN               0.348485
# 0.8       both                COLUMN_WISE          NaN               0.666667
# 0.7       both                COLUMN_WISE          NaN               0.704545
# 0.6       both                COLUMN_WISE          NaN               0.704545
# 0.5       both                COLUMN_WISE          NaN               0.704545
# 0.4       both                COLUMN_WISE          NaN               0.704545
# 0.3       both                COLUMN_WISE          NaN               0.704545
# 0.2       both                COLUMN_WISE          NaN               0.704545
# 0.1       both                COLUMN_WISE          NaN               0.704545
#
#                                                                      F1 Score  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.015038
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.701493
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  0.023506
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.736527
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   0.020619
# 1.0       threshold           COLUMN_WISE          NaN               0.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.617647
# 0.8       threshold           COLUMN_WISE          NaN               0.868327
# 0.7       threshold           COLUMN_WISE          NaN               0.825000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.738095
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.015038
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.616071
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.738095
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.738095
# 1.0       both                RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.733871
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.738095
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.738095
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.738095
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.738095
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   0.738095
# 0.3       both                RECORD_WISE          FULL_SERIALIZED   0.738095
# 0.2       both                RECORD_WISE          FULL_SERIALIZED   0.738095
# 0.1       both                RECORD_WISE          FULL_SERIALIZED   0.738095
# 1.0       both                COLUMN_WISE          NaN               0.000000
# 0.9       both                COLUMN_WISE          NaN               0.500000
# 0.8       both                COLUMN_WISE          NaN               0.730290
# 0.7       both                COLUMN_WISE          NaN               0.738095
# 0.6       both                COLUMN_WISE          NaN               0.738095
# 0.5       both                COLUMN_WISE          NaN               0.738095
# 0.4       both                COLUMN_WISE          NaN               0.738095
# 0.3       both                COLUMN_WISE          NaN               0.738095
# 0.2       both                COLUMN_WISE          NaN               0.738095
# 0.1       both                COLUMN_WISE          NaN               0.738095
#
#                                                                       tp   fn  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED    1  131
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED   94   38
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  132    0
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED     0  132
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   123    9
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   132    0
# 1.0       threshold           COLUMN_WISE          NaN                 0  132
# 0.9       threshold           COLUMN_WISE          NaN                63   69
# 0.8       threshold           COLUMN_WISE          NaN               122   10
# 0.7       threshold           COLUMN_WISE          NaN               132    0
# NaN       zero-shot-prompting RECORD_WISE          NaN                93   39
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED    1  131
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED   69   63
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED   93   39
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED   93   39
# 1.0       both                RECORD_WISE          FULL_SERIALIZED     0  132
# 0.9       both                RECORD_WISE          FULL_SERIALIZED    91   41
# 0.8       both                RECORD_WISE          FULL_SERIALIZED    93   39
# 0.7       both                RECORD_WISE          FULL_SERIALIZED    93   39
# 0.6       both                RECORD_WISE          FULL_SERIALIZED    93   39
# 0.5       both                RECORD_WISE          FULL_SERIALIZED    93   39
# 0.4       both                RECORD_WISE          FULL_SERIALIZED    93   39
# 0.3       both                RECORD_WISE          FULL_SERIALIZED    93   39
# 0.2       both                RECORD_WISE          FULL_SERIALIZED    93   39
# 0.1       both                RECORD_WISE          FULL_SERIALIZED    93   39
# 1.0       both                COLUMN_WISE          NaN                 0  132
# 0.9       both                COLUMN_WISE          NaN                46   86
# 0.8       both                COLUMN_WISE          NaN                88   44
# 0.7       both                COLUMN_WISE          NaN                93   39
# 0.6       both                COLUMN_WISE          NaN                93   39
# 0.5       both                COLUMN_WISE          NaN                93   39
# 0.4       both                COLUMN_WISE          NaN                93   39
# 0.3       both                COLUMN_WISE          NaN                93   39
# 0.2       both                COLUMN_WISE          NaN                93   39
# 0.1       both                COLUMN_WISE          NaN                93   39
#
#                                                                         fp  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED     42
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  10967
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED       0
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED      79
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   12540
# 1.0       threshold           COLUMN_WISE          NaN                   0
# 0.9       threshold           COLUMN_WISE          NaN                   9
# 0.8       threshold           COLUMN_WISE          NaN                  27
# 0.7       threshold           COLUMN_WISE          NaN                  56
# NaN       zero-shot-prompting RECORD_WISE          NaN                  27
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED     23
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED     27
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED     27
# 1.0       both                RECORD_WISE          FULL_SERIALIZED       0
# 0.9       both                RECORD_WISE          FULL_SERIALIZED      25
# 0.8       both                RECORD_WISE          FULL_SERIALIZED      27
# 0.7       both                RECORD_WISE          FULL_SERIALIZED      27
# 0.6       both                RECORD_WISE          FULL_SERIALIZED      27
# 0.5       both                RECORD_WISE          FULL_SERIALIZED      27
# 0.4       both                RECORD_WISE          FULL_SERIALIZED      27
# 0.3       both                RECORD_WISE          FULL_SERIALIZED      27
# 0.2       both                RECORD_WISE          FULL_SERIALIZED      27
# 0.1       both                RECORD_WISE          FULL_SERIALIZED      27
# 1.0       both                COLUMN_WISE          NaN                   0
# 0.9       both                COLUMN_WISE          NaN                   6
# 0.8       both                COLUMN_WISE          NaN                  21
# 0.7       both                COLUMN_WISE          NaN                  27
# 0.6       both                COLUMN_WISE          NaN                  27
# 0.5       both                COLUMN_WISE          NaN                  27
# 0.4       both                COLUMN_WISE          NaN                  27
# 0.3       both                COLUMN_WISE          NaN                  27
# 0.2       both                COLUMN_WISE          NaN                  27
# 0.1       both                COLUMN_WISE          NaN                  27
#
#                                                                         runtime  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED    2.838552
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED    1.536983
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED    1.545310
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED    1.565419
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED    1.549400
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED    1.552420
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED    1.525844
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED    1.565871
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED    1.657646
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED     1.831528
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED     1.808583
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED     1.937043
# 1.0       threshold           COLUMN_WISE          NaN                 1.983470
# 0.9       threshold           COLUMN_WISE          NaN                 2.237076
# 0.8       threshold           COLUMN_WISE          NaN                 2.508479
# 0.7       threshold           COLUMN_WISE          NaN                 2.852538
# NaN       zero-shot-prompting RECORD_WISE          NaN               749.751319
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED    1.597990
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED    1.564640
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED    1.556895
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED    1.551682
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED    1.552390
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED    1.546779
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED    1.595889
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED    8.010143
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  524.570307
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  749.930566
# 1.0       both                RECORD_WISE          FULL_SERIALIZED     1.856456
# 0.9       both                RECORD_WISE          FULL_SERIALIZED    11.347157
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   597.484924
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   749.421003
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   750.041443
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   749.032580
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   750.779637
# 0.3       both                RECORD_WISE          FULL_SERIALIZED   751.905001
# 0.2       both                RECORD_WISE          FULL_SERIALIZED   749.240125
# 0.1       both                RECORD_WISE          FULL_SERIALIZED   749.461321
# 1.0       both                COLUMN_WISE          NaN                 1.999311
# 0.9       both                COLUMN_WISE          NaN                 5.559405
# 0.8       both                COLUMN_WISE          NaN                 9.567352
# 0.7       both                COLUMN_WISE          NaN                11.779592
# 0.6       both                COLUMN_WISE          NaN                14.916903
# 0.5       both                COLUMN_WISE          NaN                60.855041
# 0.4       both                COLUMN_WISE          NaN               466.937476
# 0.3       both                COLUMN_WISE          NaN               746.997432
# 0.2       both                COLUMN_WISE          NaN               754.628982
# 0.1       both                COLUMN_WISE          NaN               751.936087
#
#                                                                                                                   pred  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED                                    {(6235, 13724)}
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  {(2743, 17193), (1778, 33431), (1490, 3901), (...
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  {(2914, 43724), (1596, 31105), (1165, 825), (1...
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED                                                  {}
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   {(3772, 38465), (5734, 7760), (2743, 17193), (...
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   {(2914, 43724), (3927, 5685), (4302, 40500), (...
# 1.0       threshold           COLUMN_WISE          NaN                                                              {}
# 0.9       threshold           COLUMN_WISE          NaN               {(5364, 47946), (509, 55936), (3871, 23952), (...
# 0.8       threshold           COLUMN_WISE          NaN               {(6533, 38335), (2813, 47885), (1490, 3901), (...
# 0.7       threshold           COLUMN_WISE          NaN               {(2743, 17193), (1778, 33431), (6533, 38335), ...
# NaN       zero-shot-prompting RECORD_WISE          NaN               {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED                                    {(6235, 13724)}
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  {(1490, 3901), (206, 41214), (4748, 5685), (43...
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 1.0       both                RECORD_WISE          FULL_SERIALIZED                                                  {}
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.3       both                RECORD_WISE          FULL_SERIALIZED   {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.2       both                RECORD_WISE          FULL_SERIALIZED   {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.1       both                RECORD_WISE          FULL_SERIALIZED   {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 1.0       both                COLUMN_WISE          NaN                                                              {}
# 0.9       both                COLUMN_WISE          NaN               {(5364, 47946), (509, 55936), (1656, 49516), (...
# 0.8       both                COLUMN_WISE          NaN               {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.7       both                COLUMN_WISE          NaN               {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.6       both                COLUMN_WISE          NaN               {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.5       both                COLUMN_WISE          NaN               {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.4       both                COLUMN_WISE          NaN               {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.3       both                COLUMN_WISE          NaN               {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.2       both                COLUMN_WISE          NaN               {(2813, 47885), (1490, 3901), (206, 41214), (4...
# 0.1       both                COLUMN_WISE          NaN               {(2813, 47885), (1490, 3901), (206, 41214), (4...
#
#                                                                         bleu1  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.351403
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.883405
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.981024
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.768695
# 0.8       threshold           COLUMN_WISE          NaN               0.972785
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.883162
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.351403
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.792485
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.883162
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.883162
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.875506
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.883162
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.883162
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.883162
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.883162
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   0.883162
# 0.3       both                RECORD_WISE          FULL_SERIALIZED   0.883162
# 0.2       both                RECORD_WISE          FULL_SERIALIZED   0.883162
# 0.1       both                RECORD_WISE          FULL_SERIALIZED   0.883162
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN               0.700100
# 0.8       both                COLUMN_WISE          NaN               0.858995
# 0.7       both                COLUMN_WISE          NaN               0.883162
# 0.6       both                COLUMN_WISE          NaN               0.883162
# 0.5       both                COLUMN_WISE          NaN               0.883162
# 0.4       both                COLUMN_WISE          NaN               0.883162
# 0.3       both                COLUMN_WISE          NaN               0.883162
# 0.2       both                COLUMN_WISE          NaN               0.883162
# 0.1       both                COLUMN_WISE          NaN               0.883162
#
#                                                                         bleu2  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.215811
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.851309
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.975707
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.709853
# 0.8       threshold           COLUMN_WISE          NaN               0.964269
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.852239
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.215811
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.734656
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.852239
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.852239
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.842323
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.852239
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.852239
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.852239
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.852239
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   0.852239
# 0.3       both                RECORD_WISE          FULL_SERIALIZED   0.852239
# 0.2       both                RECORD_WISE          FULL_SERIALIZED   0.852239
# 0.1       both                RECORD_WISE          FULL_SERIALIZED   0.852239
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN               0.620350
# 0.8       both                COLUMN_WISE          NaN               0.820976
# 0.7       both                COLUMN_WISE          NaN               0.852239
# 0.6       both                COLUMN_WISE          NaN               0.852239
# 0.5       both                COLUMN_WISE          NaN               0.852239
# 0.4       both                COLUMN_WISE          NaN               0.852239
# 0.3       both                COLUMN_WISE          NaN               0.852239
# 0.2       both                COLUMN_WISE          NaN               0.852239
# 0.1       both                COLUMN_WISE          NaN               0.852239
#
#                                                                         bleu3  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.157853
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.832391
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.972209
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.672419
# 0.8       threshold           COLUMN_WISE          NaN               0.958860
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.832440
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.157853
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.700841
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.832440
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.832440
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.821210
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.832440
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.832440
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.832440
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.832440
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   0.832440
# 0.3       both                RECORD_WISE          FULL_SERIALIZED   0.832440
# 0.2       both                RECORD_WISE          FULL_SERIALIZED   0.832440
# 0.1       both                RECORD_WISE          FULL_SERIALIZED   0.832440
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN               0.572184
# 0.8       both                COLUMN_WISE          NaN               0.796544
# 0.7       both                COLUMN_WISE          NaN               0.832440
# 0.6       both                COLUMN_WISE          NaN               0.832440
# 0.5       both                COLUMN_WISE          NaN               0.832440
# 0.4       both                COLUMN_WISE          NaN               0.832440
# 0.3       both                COLUMN_WISE          NaN               0.832440
# 0.2       both                COLUMN_WISE          NaN               0.832440
# 0.1       both                COLUMN_WISE          NaN               0.832440
#
#                                                                         bleu4
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.118150
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.817656
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.969507
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.643116
# 0.8       threshold           COLUMN_WISE          NaN               0.954607
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.816241
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.118150
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.675247
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.816241
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.816241
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.804017
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.816241
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.816241
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.816241
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.816241
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   0.816241
# 0.3       both                RECORD_WISE          FULL_SERIALIZED   0.816241
# 0.2       both                RECORD_WISE          FULL_SERIALIZED   0.816241
# 0.1       both                RECORD_WISE          FULL_SERIALIZED   0.816241
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN               0.535304
# 0.8       both                COLUMN_WISE          NaN               0.776940
# 0.7       both                COLUMN_WISE          NaN               0.816241
# 0.6       both                COLUMN_WISE          NaN               0.816241
# 0.5       both                COLUMN_WISE          NaN               0.816241
# 0.4       both                COLUMN_WISE          NaN               0.816241
# 0.3       both                COLUMN_WISE          NaN               0.816241
# 0.2       both                COLUMN_WISE          NaN               0.816241
# 0.1       both                COLUMN_WISE          NaN               0.816241

# %%
name = "iTunesAmazon_mpnetBaseV2_LLama3B"
df_evaluation_results.drop(columns=["pred"]).to_csv(f"{name}.csv")
df_evaluation_results.to_pickle(f"{name}.pkl")
