# %% [markdown]
# # Evaluation of Data Integration
#
# In this notebook, we evaluate how effective two relations can be integrated using the soft join operator.
# Therefore, we utilize the [Datasets for DeepMatcher paper](https://github.com/anhaidgroup/deepmatcher/blob/master/Datasets.md).
#
# The datasets contain two relations with the same entities from two different sources.
# E.g. `iTunes-Amazon` contains song records obtained from iTunes and Amazon. So, the task is to identify same songs.
#
# To test different Models, datasets, ..., there are parameters in the [modifications](#modifications) section.
# **Modfy Code in [Modifications](#modifications) Section Only!**
#
# We calculate:
# * $ TP = \text{True Matches} \cap \text{Predicted Matches} $
# * $ FN = \text{True Matches} \setminus \text{Predicted Matches} $
# * $ FP = \text{Predicted Matches} \setminus \text{True Matches} $
#
# To determine the scores:
# * $ Precision = \frac{TP}{TP + FP}$
# * $ Recall = \frac{TP}{TP + FN}$
# * $ F_1 = \frac{2 \cdot precision \cdot recall}{precision + recall} $
# * BLEU 1-4
#
# ## Imports

# %%
# %%capture
# !rm -rf SofteningQueryEvaluation
# !git clone https://github.com/HackerBschor/SofteningQueryEvaluation
# %cd SofteningQueryEvaluation

# !pip3 install faiss-gpu-cu12

# !pip3 install pgvector

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import time
import json
import tqdm
import pandas as pd


from db.operators import Dummy, InnerSoftJoin

from models import ModelMgr
from models.embedding.SentenceTransformer import SentenceTransformerEmbeddingModel
from models.semantic_validation import LLaMAValidationModel

from evaluation.util import calculate_metrics, calc_bleu

# %%
with open("evaluation/DataIntegration/DataIntegration.json") as f:
    datasets = json.load(f)

print(", ".join(datasets.keys()))

# %% [markdown]
# ## Modifications

# %%
dataset_name = "iTunesAmazon" # The tested dataset

significant_columns_left = ["Album_Name", "Artist_Name", "Released", "Song_Name", "Time"]
significant_columns_right = ["Album_Name", "Artist_Name", "Released", "Song_Name", "Time"]

# %%
# Models
# meta-llama/Llama-3.2-3B-Instruct
# meta-llama/Meta-Llama-3-8B-Instruct
stem = SentenceTransformerEmbeddingModel(ModelMgr())
lsv = LLaMAValidationModel(ModelMgr(), model_path="meta-llama/Meta-Llama-3-8B-Instruct")

# %% [markdown]
# ## Function and Dataset Declarations

# %%
significant_columns_left = [f"left_{x}" for x in significant_columns_left]
significant_columns_right = [f"right_{x}" for x in significant_columns_right]

# %%
dataset = datasets[dataset_name]
matches = pd.DataFrame(dataset["matches"])
matches.head(2)

# %%
left = pd.DataFrame(dataset["left"])
left.rename(columns={c: f"left_{c}" for c in left.columns}, inplace=True)
left.head(2)

# %%
right = pd.DataFrame(dataset["right"])
right.rename(columns={c: f"right_{c}" for c in right.columns}, inplace=True)
right.head(2)

# %%
candidates = matches\
    .merge(left, left_on=matches.columns[0], right_on=f"left_{matches.columns[0]}")\
    .merge(right, left_on=matches.columns[1], right_on=f"right_{matches.columns[1]}")\
    .drop(columns=matches.columns)

candidates.head(2)
# Out:
#    left_snoLeft left_Album_Name left_Album_Price left_Artist_Name  \
# 0           111             VHS           $7.99     X Ambassadors
# 1           148  Title (Deluxe)          $12.99    Meghan Trainor
#
#                                       left_CopyRight  left_Customer_Rating  \
# 0               2015 KIDinaKORNER/Interscope Records               4.54839
# 1   2014, 2015 Epic Records, a division of Sony M...               4.06740
#
#                                  left_Genre left_Price left_Released  \
# 0  Alternative,Music,Rock,Adult Alternative     $1.29      30-Jun-15
# 1    Pop,Music,Rock,Pop/Rock,Dance,Teen Pop     $1.29       9-Jan-15
#
#           left_Song_Name  ... right_snoRight  right_Album_Name  \
# 0  VHS Outro (Interlude)  ...          53124    VHS [Explicit]
# 1                 Credit  ...          50767    Title (Deluxe)
#
#   right_Artist_Name                   right_Song_Name right_Price right_Time  \
# 0     X Ambassadors  VHS Outro (Interlude) [Explicit]       $1.29       1:25
# 1    Meghan Trainor                            Credit       $1.29       2:51
#
#      right_Released                       right_Label  \
# 0     June 30, 2015   KIDinaKORNER/Interscope Records
# 1   January 9, 2015                              Epic
#
#                                      right_Copyright       right_Genre
# 0           (C) 2015 KIDinaKORNER/Interscope Records  Alternative Rock
# 1   2011 What A Music Ltd, licence exclusive Parl...               Pop
#
# [2 rows x 21 columns]

# %%
gt = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for _, x in candidates.iterrows()}
print(str(gt)[0:500] + "...")
# Out:
# {(2743, 17193), (6533, 38335), (5713, 35091), (1490, 3901), (206, 41214), (4748, 5685), (4302, 29727), (3763, 38465), (1165, 28023), (1070, 11280), (2223, 816), (2783, 31567), (1898, 51663), (3772, 38476), (427, 33316), (538, 1879), (250, 53124), (4414, 42138), (3325, 7406), (3422, 34354), (3945, 18982), (4588, 26169), (2480, 33820), (1152, 53319), (593, 43724), (4660, 41125), (3851, 9123), (255, 49141), (3357, 39370), (669, 24650), (3927, 16409), (6048, 4670), (6219, 29615), (1407, 48324), (610...

# %% [markdown]
# ### Execute Operator and Evaluate

# %%
def evaluate(em, sv, threshold, method, embedding_comparison, embedding_method):
    key = (threshold, method, embedding_comparison, embedding_method)

    op1 = Dummy("ltable", left.columns, list(left.values))
    op2 = Dummy("rtable", right.columns, list(right.values))

    op = InnerSoftJoin(
        op1, op2, em=em, sv=sv,
        threshold=threshold, method=method,
        columns_left=significant_columns_left, columns_right=significant_columns_right,
        embedding_comparison=embedding_comparison,
        embedding_method = embedding_method,
        zs_system_prompt = 'You are an object-matcher. Check if the two tuples A and B refere to the same real worl entity. If so, answer with "yes", if not, answer with"no" only',
        zs_template = "A is {a}\nB is {b}"
    )

    tic = time.time()
    result = op.open().fetch_all()
    toc = time.time()
    pred = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for x in result}

    scores = calculate_metrics(gt, pred, toc - tic)

    print(key, scores["F1 Score"])

    return key, scores

# %% [markdown]
# ## Evaluation

# %%
thresholds = [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

evaluation_results = {}

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "threshold", embedding_comparison = "RECORD_WISE", embedding_method = "FIELD_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.9, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.8, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.7, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.6, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.5, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.4, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.015037593984962407
# (0.3, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.7014925373134329
# (0.2, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.023506366307541625

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "threshold", embedding_comparison = "RECORD_WISE", embedding_method = "FULL_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0
# (0.9, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7365269461077845
# (0.8, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0.020618556701030924

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "threshold", embedding_comparison = "COLUMN_WISE", embedding_method = None)
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'threshold', 'COLUMN_WISE', None) 0
# (0.9, 'threshold', 'COLUMN_WISE', None) 0.6176470588235294
# (0.8, 'threshold', 'COLUMN_WISE', None) 0.8683274021352313
# (0.7, 'threshold', 'COLUMN_WISE', None) 0.825

# %%
res = evaluate(stem, lsv, method = "zero-shot-prompting", threshold = None, embedding_comparison = "RECORD_WISE", embedding_method = None)
evaluation_results[res[0]] = res[1]
# Out:
# (None, 'zero-shot-prompting', 'RECORD_WISE', None) 0.7659574468085106

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "RECORD_WISE", embedding_method = "FIELD_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.9, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.8, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.7, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.6, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.5, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.4, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.015037593984962407
# (0.3, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.7054263565891473
# (0.2, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.7659574468085106
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-2d494c3510ba> in <cell line: 0>()
#       1 for t in thresholds:
# ----> 2     res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "RECORD_WISE", embedding_method = "FIELD_SERIALIZED")
#       3     evaluation_results[res[0]] = res[1]
#       4     if res[1]["Recall"] == 1.0:
#       5         break
#
# <ipython-input-13-f05ceccab72c> in evaluate(em, sv, threshold, method, embedding_comparison, embedding_method)
#      16
#      17     tic = time.time()
# ---> 18     result = op.open().fetch_all()
#      19     toc = time.time()
#      20     pred = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for x in result}
#
# /content/SofteningQueryEvaluation/db/operators/Operator.py in fetch_all(self)
#      43
#      44     def fetch_all(self): # Interface for user to retrieve all records
# ---> 45         return list(self)
#      46
#      47     def fetch_one(self): # Interface for user to retrieve next record
#
# /content/SofteningQueryEvaluation/db/operators/Join.py in __next__(self)
#     472
#     473                     # entity matching not passing -> continue with next left record
# --> 474                     if not self.sv(prompt, system_prompt=self.zs_system_prompt):
#     475                         logging.debug(f"Prompt: \"{prompt}\" filed in semantic validation")
#     476                         continue
#
# /content/SofteningQueryEvaluation/models/semantic_validation/LLaMA.py in __call__(self, prompt, system_prompt)
#      56             attention_mask = attention_mask.cuda()
#      57
# ---> 58         answer_tok = self._model.generate(prompt_tok, attention_mask = attention_mask, **self.generation_config)
#      59         answer = self._tokenizer.decode( answer_tok[0][len(prompt_tok[0]):], skip_special_tokens=True ).lower()
#      60
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2253
#    2254             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2255             result = self._sample(
#    2256                 input_ids,
#    2257                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3252
#    3253             if is_prefill:
# -> 3254                 outputs = self(**model_inputs, return_dict=True)
#    3255                 is_prefill = False
#    3256             else:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **kwargs)
#     832
#     833         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 834         outputs = self.model(
#     835             input_ids=input_ids,
#     836             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **flash_attn_kwargs)
#     590                 )
#     591             else:
# --> 592                 layer_outputs = decoder_layer(
#     593                     hidden_states,
#     594                     attention_mask=causal_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     348         # Fully Connected
#     349         residual = hidden_states
# --> 350         hidden_states = self.post_attention_layernorm(hidden_states)
#     351         hidden_states = self.mlp(hidden_states)
#     352         hidden_states = residual + hidden_states
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states)
#      68     def forward(self, hidden_states):
#      69         input_dtype = hidden_states.dtype
# ---> 70         hidden_states = hidden_states.to(torch.float32)
#      71         variance = hidden_states.pow(2).mean(-1, keepdim=True)
#      72         hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
#
# KeyboardInterrupt:

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "RECORD_WISE", embedding_method = "FULL_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0
# (0.9, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.8135593220338982
# (0.8, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7659574468085106
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-5aaae48b5a07> in <cell line: 0>()
#       1 for t in thresholds:
# ----> 2     res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "RECORD_WISE", embedding_method = "FULL_SERIALIZED")
#       3     evaluation_results[res[0]] = res[1]
#       4     if res[1]["Recall"] == 1.0:
#       5         break
#
# <ipython-input-13-f05ceccab72c> in evaluate(em, sv, threshold, method, embedding_comparison, embedding_method)
#      16
#      17     tic = time.time()
# ---> 18     result = op.open().fetch_all()
#      19     toc = time.time()
#      20     pred = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for x in result}
#
# /content/SofteningQueryEvaluation/db/operators/Operator.py in fetch_all(self)
#      43
#      44     def fetch_all(self): # Interface for user to retrieve all records
# ---> 45         return list(self)
#      46
#      47     def fetch_one(self): # Interface for user to retrieve next record
#
# /content/SofteningQueryEvaluation/db/operators/Join.py in __next__(self)
#     472
#     473                     # entity matching not passing -> continue with next left record
# --> 474                     if not self.sv(prompt, system_prompt=self.zs_system_prompt):
#     475                         logging.debug(f"Prompt: \"{prompt}\" filed in semantic validation")
#     476                         continue
#
# /content/SofteningQueryEvaluation/models/semantic_validation/LLaMA.py in __call__(self, prompt, system_prompt)
#      39
#      40     def __call__(self, prompt: str, system_prompt: str | None = None) -> bool:
# ---> 41         self.model_to_cuda()
#      42
#      43         system_prompt = system_prompt if system_prompt else self._system_prompt
#
# /content/SofteningQueryEvaluation/models/__init__.py in model_to_cuda(self)
#      39         if torch.cuda.is_available():
#      40             self._model_mgr.get_gpu_resources(self)
# ---> 41             self._model.cuda()
#      42
#      43     def __str__(self):
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in cuda(self, *args, **kwargs)
#    3068                 )
#    3069         else:
# -> 3070             return super().cuda(*args, **kwargs)
#    3071
#    3072     @wraps(torch.nn.Module.to)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in cuda(self, device)
#    1051             Module: self
#    1052         """
# -> 1053         return self._apply(lambda t: t.cuda(device))
#    1054
#    1055     def ipu(self: T, device: Optional[Union[int, device]] = None) -> T:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     901         if recurse:
#     902             for module in self.children():
# --> 903                 module._apply(fn)
#     904
#     905         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     901         if recurse:
#     902             for module in self.children():
# --> 903                 module._apply(fn)
#     904
#     905         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     928             # `with torch.no_grad():`
#     929             with torch.no_grad():
# --> 930                 param_applied = fn(param)
#     931             p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     932
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in <lambda>(t)
#    1051             Module: self
#    1052         """
# -> 1053         return self._apply(lambda t: t.cuda(device))
#    1054
#    1055     def ipu(self: T, device: Optional[Union[int, device]] = None) -> T:
#
# KeyboardInterrupt:

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "COLUMN_WISE", embedding_method = None)
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'both', 'COLUMN_WISE', None) 0
# (0.9, 'both', 'COLUMN_WISE', None) 0.6108374384236452
# (0.8, 'both', 'COLUMN_WISE', None) 0.8519855595667869
# (0.7, 'both', 'COLUMN_WISE', None) 0.8289473684210527
# (0.6, 'both', 'COLUMN_WISE', None) 0.780185758513932
# (0.5, 'both', 'COLUMN_WISE', None) 0.7682926829268294
# (0.4, 'both', 'COLUMN_WISE', None) 0.7659574468085106
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-97b6a3f82786> in <cell line: 0>()
#       1 for t in thresholds:
# ----> 2     res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "COLUMN_WISE", embedding_method = None)
#       3     evaluation_results[res[0]] = res[1]
#       4     if res[1]["Recall"] == 1.0:
#       5         break
#
# <ipython-input-13-f05ceccab72c> in evaluate(em, sv, threshold, method, embedding_comparison, embedding_method)
#      16
#      17     tic = time.time()
# ---> 18     result = op.open().fetch_all()
#      19     toc = time.time()
#      20     pred = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for x in result}
#
# /content/SofteningQueryEvaluation/db/operators/Operator.py in fetch_all(self)
#      43
#      44     def fetch_all(self): # Interface for user to retrieve all records
# ---> 45         return list(self)
#      46
#      47     def fetch_one(self): # Interface for user to retrieve next record
#
# /content/SofteningQueryEvaluation/db/operators/Join.py in __next__(self)
#     472
#     473                     # entity matching not passing -> continue with next left record
# --> 474                     if not self.sv(prompt, system_prompt=self.zs_system_prompt):
#     475                         logging.debug(f"Prompt: \"{prompt}\" filed in semantic validation")
#     476                         continue
#
# /content/SofteningQueryEvaluation/models/semantic_validation/LLaMA.py in __call__(self, prompt, system_prompt)
#      52
#      53         if torch.cuda.is_available():
# ---> 54             self._model.to("cuda")
#      55             prompt_tok = prompt_tok.cuda()
#      56             attention_mask = attention_mask.cuda()
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in to(self, *args, **kwargs)
#    3108                     " `dtype` by passing the correct `torch_dtype` argument."
#    3109                 )
# -> 3110         return super().to(*args, **kwargs)
#    3111
#    3112     def half(self, *args):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1341                     raise
#    1342
# -> 1343         return self._apply(convert)
#    1344
#    1345     def register_full_backward_pre_hook(
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     901         if recurse:
#     902             for module in self.children():
# --> 903                 module._apply(fn)
#     904
#     905         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     901         if recurse:
#     902             for module in self.children():
# --> 903                 module._apply(fn)
#     904
#     905         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     901         if recurse:
#     902             for module in self.children():
# --> 903                 module._apply(fn)
#     904
#     905         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     901         if recurse:
#     902             for module in self.children():
# --> 903                 module._apply(fn)
#     904
#     905         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     928             # `with torch.no_grad():`
#     929             with torch.no_grad():
# --> 930                 param_applied = fn(param)
#     931             p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     932
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in convert(t)
#    1327                         memory_format=convert_to_format,
#    1328                     )
# -> 1329                 return t.to(
#    1330                     device,
#    1331                     dtype if t.is_floating_point() or t.is_complex() else None,
#
# KeyboardInterrupt:

# %%
gt_blue = {tuple(row[col] for col in list(left.columns) + list(right.columns)) for _, row in candidates.iterrows()}

for key in tqdm.tqdm(evaluation_results):
    result = pd.DataFrame(evaluation_results[key]["pred"], columns=["l", "r"])\
        .merge(left, left_on="l", right_on="left_snoLeft")\
        .merge(right, left_on="r", right_on="right_snoRight")

    pred_blue = {tuple(row[col] for col in list(left.columns) + list(right.columns)) for _, row in result.iterrows()}
    scores_bleu = calc_bleu(gt_blue, pred_blue)
    for score_bleu in scores_bleu:
        evaluation_results[key][score_bleu] = scores_bleu[score_bleu]
# Out:
# 100%|██████████| 36/36 [09:30<00:00, 15.84s/it]

# %%
keys = ["threshold", "method", "embedding_comparison", "embedding_method"]
evaluation_results_list = [v | {ki: vi for ki, vi in zip(keys, k)} for k, v in evaluation_results.items()]
df_evaluation_results = pd.DataFrame.from_records(evaluation_results_list, index=keys)
df_evaluation_results
# Out:
#                                                                      Precision  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED   1.000000
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED   0.691176
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED   0.011893
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED    0.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED    0.608911
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED    0.010417
# 1.0       threshold           COLUMN_WISE          NaN                0.000000
# 0.9       threshold           COLUMN_WISE          NaN                0.875000
# 0.8       threshold           COLUMN_WISE          NaN                0.818792
# 0.7       threshold           COLUMN_WISE          NaN                0.702128
# NaN       zero-shot-prompting RECORD_WISE          NaN                0.639594
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED   1.000000
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED   0.722222
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED   0.639594
# 1.0       both                RECORD_WISE          FULL_SERIALIZED    0.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED    0.736196
# 0.8       both                RECORD_WISE          FULL_SERIALIZED    0.639594
# 1.0       both                COLUMN_WISE          NaN                0.000000
# 0.9       both                COLUMN_WISE          NaN                0.873239
# 0.8       both                COLUMN_WISE          NaN                0.813793
# 0.7       both                COLUMN_WISE          NaN                0.732558
# 0.6       both                COLUMN_WISE          NaN                0.659686
# 0.5       both                COLUMN_WISE          NaN                0.642857
# 0.4       both                COLUMN_WISE          NaN                0.639594
#
#                                                                        Recall  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.007576
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.712121
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.931818
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN               0.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.477273
# 0.8       threshold           COLUMN_WISE          NaN               0.924242
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.954545
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.007576
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.689394
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.954545
# 1.0       both                RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.909091
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.954545
# 1.0       both                COLUMN_WISE          NaN               0.000000
# 0.9       both                COLUMN_WISE          NaN               0.469697
# 0.8       both                COLUMN_WISE          NaN               0.893939
# 0.7       both                COLUMN_WISE          NaN               0.954545
# 0.6       both                COLUMN_WISE          NaN               0.954545
# 0.5       both                COLUMN_WISE          NaN               0.954545
# 0.4       both                COLUMN_WISE          NaN               0.954545
#
#                                                                      F1 Score  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.015038
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.701493
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  0.023506
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.736527
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   0.020619
# 1.0       threshold           COLUMN_WISE          NaN               0.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.617647
# 0.8       threshold           COLUMN_WISE          NaN               0.868327
# 0.7       threshold           COLUMN_WISE          NaN               0.825000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.765957
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.015038
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.705426
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.765957
# 1.0       both                RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.813559
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.765957
# 1.0       both                COLUMN_WISE          NaN               0.000000
# 0.9       both                COLUMN_WISE          NaN               0.610837
# 0.8       both                COLUMN_WISE          NaN               0.851986
# 0.7       both                COLUMN_WISE          NaN               0.828947
# 0.6       both                COLUMN_WISE          NaN               0.780186
# 0.5       both                COLUMN_WISE          NaN               0.768293
# 0.4       both                COLUMN_WISE          NaN               0.765957
#
#                                                                       tp   fn  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED    1  131
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED   94   38
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  132    0
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED     0  132
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   123    9
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   132    0
# 1.0       threshold           COLUMN_WISE          NaN                 0  132
# 0.9       threshold           COLUMN_WISE          NaN                63   69
# 0.8       threshold           COLUMN_WISE          NaN               122   10
# 0.7       threshold           COLUMN_WISE          NaN               132    0
# NaN       zero-shot-prompting RECORD_WISE          NaN               126    6
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED    1  131
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED   91   41
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  126    6
# 1.0       both                RECORD_WISE          FULL_SERIALIZED     0  132
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   120   12
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   126    6
# 1.0       both                COLUMN_WISE          NaN                 0  132
# 0.9       both                COLUMN_WISE          NaN                62   70
# 0.8       both                COLUMN_WISE          NaN               118   14
# 0.7       both                COLUMN_WISE          NaN               126    6
# 0.6       both                COLUMN_WISE          NaN               126    6
# 0.5       both                COLUMN_WISE          NaN               126    6
# 0.4       both                COLUMN_WISE          NaN               126    6
#
#                                                                         fp  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED     42
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  10967
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED       0
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED      79
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   12540
# 1.0       threshold           COLUMN_WISE          NaN                   0
# 0.9       threshold           COLUMN_WISE          NaN                   9
# 0.8       threshold           COLUMN_WISE          NaN                  27
# 0.7       threshold           COLUMN_WISE          NaN                  56
# NaN       zero-shot-prompting RECORD_WISE          NaN                  71
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED     35
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED     71
# 1.0       both                RECORD_WISE          FULL_SERIALIZED       0
# 0.9       both                RECORD_WISE          FULL_SERIALIZED      43
# 0.8       both                RECORD_WISE          FULL_SERIALIZED      71
# 1.0       both                COLUMN_WISE          NaN                   0
# 0.9       both                COLUMN_WISE          NaN                   9
# 0.8       both                COLUMN_WISE          NaN                  27
# 0.7       both                COLUMN_WISE          NaN                  46
# 0.6       both                COLUMN_WISE          NaN                  65
# 0.5       both                COLUMN_WISE          NaN                  70
# 0.4       both                COLUMN_WISE          NaN                  71
#
#                                                                          runtime  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED     2.901248
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED     1.567873
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED     1.604187
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED     1.608574
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED     1.582206
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED     1.566131
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED     1.574409
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED     1.677805
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED     1.727909
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED      1.859910
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED      1.880177
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED      1.973726
# 1.0       threshold           COLUMN_WISE          NaN                  2.048766
# 0.9       threshold           COLUMN_WISE          NaN                  2.290481
# 0.8       threshold           COLUMN_WISE          NaN                  2.569084
# 0.7       threshold           COLUMN_WISE          NaN                  2.938872
# NaN       zero-shot-prompting RECORD_WISE          NaN               1447.678818
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED     1.604059
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED     1.659308
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED     1.610795
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED     1.596034
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED     1.584640
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED     1.594769
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED     1.710161
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED    13.981309
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  1011.185104
# 1.0       both                RECORD_WISE          FULL_SERIALIZED      1.936326
# 0.9       both                RECORD_WISE          FULL_SERIALIZED     20.270281
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   1149.256489
# 1.0       both                COLUMN_WISE          NaN                  2.056848
# 0.9       both                COLUMN_WISE          NaN                  8.755584
# 0.8       both                COLUMN_WISE          NaN                 16.108415
# 0.7       both                COLUMN_WISE          NaN                 20.041152
# 0.6       both                COLUMN_WISE          NaN                 26.085107
# 0.5       both                COLUMN_WISE          NaN                114.825447
# 0.4       both                COLUMN_WISE          NaN                901.119081
#
#                                                                                                                   pred  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED                                    {(6235, 13724)}
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  {(2743, 17193), (1778, 33431), (1490, 3901), (...
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  {(2914, 43724), (1596, 31105), (1165, 825), (1...
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED                                                  {}
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   {(3772, 38465), (5734, 7760), (2743, 17193), (...
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   {(2914, 43724), (3927, 5685), (4302, 40500), (...
# 1.0       threshold           COLUMN_WISE          NaN                                                              {}
# 0.9       threshold           COLUMN_WISE          NaN               {(5364, 47946), (509, 55936), (3871, 23952), (...
# 0.8       threshold           COLUMN_WISE          NaN               {(6533, 38335), (2813, 47885), (1490, 3901), (...
# 0.7       threshold           COLUMN_WISE          NaN               {(2743, 17193), (1778, 33431), (6533, 38335), ...
# NaN       zero-shot-prompting RECORD_WISE          NaN               {(3772, 38465), (2743, 17193), (6533, 38335), ...
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED                                                 {}
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED                                    {(6235, 13724)}
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  {(2743, 17193), (1490, 3901), (206, 41214), (4...
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  {(3772, 38465), (2743, 17193), (6533, 38335), ...
# 1.0       both                RECORD_WISE          FULL_SERIALIZED                                                  {}
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   {(3772, 38465), (2743, 17193), (2813, 47885), ...
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   {(3772, 38465), (2743, 17193), (6533, 38335), ...
# 1.0       both                COLUMN_WISE          NaN                                                              {}
# 0.9       both                COLUMN_WISE          NaN               {(5364, 47946), (509, 55936), (3871, 23952), (...
# 0.8       both                COLUMN_WISE          NaN               {(6533, 38335), (2813, 47885), (1490, 3901), (...
# 0.7       both                COLUMN_WISE          NaN               {(2743, 17193), (6533, 38335), (2813, 47885), ...
# 0.6       both                COLUMN_WISE          NaN               {(3772, 38465), (2743, 17193), (6533, 38335), ...
# 0.5       both                COLUMN_WISE          NaN               {(3772, 38465), (2743, 17193), (6533, 38335), ...
# 0.4       both                COLUMN_WISE          NaN               {(3772, 38465), (2743, 17193), (6533, 38335), ...
#
#                                                                         bleu1  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.351403
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.883405
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.981024
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.768695
# 0.8       threshold           COLUMN_WISE          NaN               0.972785
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.982304
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.351403
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.872957
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.982304
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.970886
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.982304
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN               0.766843
# 0.8       both                COLUMN_WISE          NaN               0.960485
# 0.7       both                COLUMN_WISE          NaN               0.982304
# 0.6       both                COLUMN_WISE          NaN               0.982304
# 0.5       both                COLUMN_WISE          NaN               0.982304
# 0.4       both                COLUMN_WISE          NaN               0.982304
#
#                                                                         bleu2  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.215811
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.851309
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.975707
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.709853
# 0.8       threshold           COLUMN_WISE          NaN               0.964269
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.977850
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.215811
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.838190
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.977850
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.963286
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.977850
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN               0.707433
# 0.8       both                COLUMN_WISE          NaN               0.948889
# 0.7       both                COLUMN_WISE          NaN               0.977850
# 0.6       both                COLUMN_WISE          NaN               0.977850
# 0.5       both                COLUMN_WISE          NaN               0.977850
# 0.4       both                COLUMN_WISE          NaN               0.977850
#
#                                                                         bleu3  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.157853
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.832391
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.972209
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.672419
# 0.8       threshold           COLUMN_WISE          NaN               0.958860
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.974666
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.157853
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.817195
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.974666
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.958146
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.974666
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN               0.669490
# 0.8       both                COLUMN_WISE          NaN               0.941253
# 0.7       both                COLUMN_WISE          NaN               0.974666
# 0.6       both                COLUMN_WISE          NaN               0.974666
# 0.5       both                COLUMN_WISE          NaN               0.974666
# 0.4       both                COLUMN_WISE          NaN               0.974666
#
#                                                                         bleu4
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.118150
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.817656
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.969507
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.643116
# 0.8       threshold           COLUMN_WISE          NaN               0.954607
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.972250
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.118150
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.800604
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.972250
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.953977
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.972250
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN               0.639856
# 0.8       both                COLUMN_WISE          NaN               0.935389
# 0.7       both                COLUMN_WISE          NaN               0.972250
# 0.6       both                COLUMN_WISE          NaN               0.972250
# 0.5       both                COLUMN_WISE          NaN               0.972250
# 0.4       both                COLUMN_WISE          NaN               0.972250

# %%
name = "iTunesAmazon_mpnetBaseV2_LLama8B"
df_evaluation_results.drop(columns=["pred"]).to_csv(f"{name}.csv")
df_evaluation_results.to_pickle(f"{name}.pkl")
