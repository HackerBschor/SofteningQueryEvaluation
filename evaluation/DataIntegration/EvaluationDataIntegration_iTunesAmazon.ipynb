# %% [markdown]
# # Evaluation of Data Integration
#
# In this notebook, we evaluate how effective two relations can be integrated using the soft join operator.
# Therefore, we utilize the [Datasets for DeepMatcher paper](https://github.com/anhaidgroup/deepmatcher/blob/master/Datasets.md).
#
# The datasets contain two relations with the same entities from two different sources.
# E.g. `iTunes-Amazon` contains song records obtained from iTunes and Amazon. So, the task is to identify same songs.
#
# To test different Models, datasets, ..., there are parameters in the [modifications](#modifications) section.
# **Modfy Code in [Modifications](#modifications) Section Only!**
#
# We calculate:
# * $ TP = \text{True Matches} \cap \text{Predicted Matches} $
# * $ FN = \text{True Matches} \setminus \text{Predicted Matches} $
# * $ FP = \text{Predicted Matches} \setminus \text{True Matches} $
#
# To determine the scores:
# * $ Precision = \frac{TP}{TP + FP}$
# * $ Recall = \frac{TP}{TP + FN}$
# * $ F_1 = \frac{2 \cdot precision \cdot recall}{precision + recall} $
# * BLEU 1-4
#
# ## Imports

# %%
import time
import json
import tqdm
import pandas as pd


from db.operators import Dummy, InnerSoftJoin

from models import ModelMgr
from models.embedding.SentenceTransformer import SentenceTransformerEmbeddingModel
from models.semantic_validation import LLaMAValidationModel

from evaluation.util import calculate_metrics, calc_bleu
# Out:
# [nltk_data] Downloading package punkt to /home/nico/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/nico/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
with open("DataIntegration.json") as f:
    datasets = json.load(f)

# %% [markdown]
# ## Modifications

# %%
dataset_name = "iTunesAmazon" # The tested dataset

significant_columns_left = ["Album_Name", "Artist_Name", "Released", "Song_Name", "Time"]
significant_columns_right = ["Album_Name", "Artist_Name", "Released", "Song_Name", "Time"]

# %%
# Models
m = ModelMgr()
stem = SentenceTransformerEmbeddingModel(m)
lsv = LLaMAValidationModel(m)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## Function and Dataset Declarations

# %%
significant_columns_left = [f"left_{x}" for x in significant_columns_left]
significant_columns_right = [f"right_{x}" for x in significant_columns_right]

# %%
dataset = datasets[dataset_name]
matches = pd.DataFrame(dataset["matches"])
matches.head(2)
# Out:
#    snoLeft  snoRight
# 0      111     53124
# 1      148     50767

# %%
left = pd.DataFrame(dataset["left"])
left.rename(columns={c: f"left_{c}" for c in left.columns}, inplace=True)
left.head(2)
# Out:
#    left_snoLeft left_Album_Name left_Album_Price left_Artist_Name  \
# 0           111             VHS           $7.99     X Ambassadors
# 1           148  Title (Deluxe)          $12.99    Meghan Trainor
#
#                                       left_CopyRight  left_Customer_Rating  \
# 0               2015 KIDinaKORNER/Interscope Records               4.54839
# 1   2014, 2015 Epic Records, a division of Sony M...               4.06740
#
#                                  left_Genre left_Price left_Released  \
# 0  Alternative,Music,Rock,Adult Alternative     $1.29      30-Jun-15
# 1    Pop,Music,Rock,Pop/Rock,Dance,Teen Pop     $1.29       9-Jan-15
#
#           left_Song_Name left_Time
# 0  VHS Outro (Interlude)      1:25
# 1                 Credit      2:51

# %%
right = pd.DataFrame(dataset["right"])
right.rename(columns={c: f"right_{c}" for c in right.columns}, inplace=True)
right.head(2)
# Out:
#    right_snoRight right_Album_Name right_Artist_Name  \
# 0             363           #NAME?        Ed Sheeran
# 1             379           #NAME?        Ed Sheeran
#
#             right_Song_Name right_Price right_Time      right_Released  \
# 0  Sunburn (Deluxe Edition)       $1.29       4:35   September 9, 2011
# 1  Sunburn (Deluxe Edition)       $1.29       4:35   September 9, 2011
#
#             right_Label right_Copyright right_Genre
# 0   Atlantic Records UK    Doll records         Pop
# 1   Atlantic Records UK    Doll records         Pop

# %%
candidates = matches\
    .merge(left, left_on=matches.columns[0], right_on=f"left_{matches.columns[0]}")\
    .merge(right, left_on=matches.columns[1], right_on=f"right_{matches.columns[1]}")\
    .drop(columns=matches.columns)

candidates.head(2)
# Out:
#    left_snoLeft left_Album_Name left_Album_Price left_Artist_Name  \
# 0           111             VHS           $7.99     X Ambassadors
# 1           148  Title (Deluxe)          $12.99    Meghan Trainor
#
#                                       left_CopyRight  left_Customer_Rating  \
# 0               2015 KIDinaKORNER/Interscope Records               4.54839
# 1   2014, 2015 Epic Records, a division of Sony M...               4.06740
#
#                                  left_Genre left_Price left_Released  \
# 0  Alternative,Music,Rock,Adult Alternative     $1.29      30-Jun-15
# 1    Pop,Music,Rock,Pop/Rock,Dance,Teen Pop     $1.29       9-Jan-15
#
#           left_Song_Name  ... right_snoRight  right_Album_Name  \
# 0  VHS Outro (Interlude)  ...          53124    VHS [Explicit]
# 1                 Credit  ...          50767    Title (Deluxe)
#
#   right_Artist_Name                   right_Song_Name right_Price right_Time  \
# 0     X Ambassadors  VHS Outro (Interlude) [Explicit]       $1.29       1:25
# 1    Meghan Trainor                            Credit       $1.29       2:51
#
#      right_Released                       right_Label  \
# 0     June 30, 2015   KIDinaKORNER/Interscope Records
# 1   January 9, 2015                              Epic
#
#                                      right_Copyright       right_Genre
# 0           (C) 2015 KIDinaKORNER/Interscope Records  Alternative Rock
# 1   2011 What A Music Ltd, licence exclusive Parl...               Pop
#
# [2 rows x 21 columns]

# %%
gt = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for _, x in candidates.iterrows()}
print(str(gt)[0:500] + "...")
# Out:
# {(2743, 17193), (6533, 38335), (5713, 35091), (1490, 3901), (206, 41214), (4748, 5685), (4302, 29727), (3763, 38465), (1165, 28023), (1070, 11280), (2223, 816), (2783, 31567), (1898, 51663), (3772, 38476), (427, 33316), (538, 1879), (250, 53124), (4414, 42138), (3325, 7406), (3422, 34354), (3945, 18982), (4588, 26169), (2480, 33820), (1152, 53319), (593, 43724), (4660, 41125), (3851, 9123), (255, 49141), (3357, 39370), (669, 24650), (3927, 16409), (6048, 4670), (6219, 29615), (1407, 48324), (610...

# %% [markdown]
# ### Execute Operator and Evaluate

# %%
def evaluate(em, sv, threshold, method, embedding_comparison, embedding_method):
    key = (threshold, method, embedding_comparison, embedding_method)

    op1 = Dummy("ltable", left.columns, list(left.values))
    op2 = Dummy("rtable", right.columns, list(right.values))

    op = InnerSoftJoin(
        op1, op2, em=em, sv=sv,
        threshold=threshold, method=method,
        columns_left=significant_columns_left, columns_right=significant_columns_right,
        embedding_comparison=embedding_comparison,
        embedding_method = embedding_method
    )

    tic = time.time()
    result = op.open().fetch_all()
    toc = time.time()
    pred = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for x in result}

    scores = calculate_metrics(gt, pred, toc - tic)

    print(key, scores["F1 Score"])

    return key, scores

# %% [markdown]
# ## Evaluation

# %%
thresholds = [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

evaluation_results = {}

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "threshold", embedding_comparison = "RECORD_WISE", embedding_method = "FIELD_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.9, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.8, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.7, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.6, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.5, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.4, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.015037593984962407
# (0.3, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.7014925373134329
# (0.2, 'threshold', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.023506366307541625

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "threshold", embedding_comparison = "RECORD_WISE", embedding_method = "FULL_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0
# (0.9, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0.7365269461077845
# (0.8, 'threshold', 'RECORD_WISE', 'FULL_SERIALIZED') 0.020618556701030924

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "threshold", embedding_comparison = "COLUMN_WISE", embedding_method = None)
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'threshold', 'COLUMN_WISE', None) 0
# (0.9, 'threshold', 'COLUMN_WISE', None) 0.6176470588235294
# (0.8, 'threshold', 'COLUMN_WISE', None) 0.8683274021352313
# (0.7, 'threshold', 'COLUMN_WISE', None) 0.825

# %%
res = evaluate(stem, lsv, method = "zero-shot-prompting", threshold = None, embedding_comparison = "RECORD_WISE", embedding_method = None)
evaluation_results[res[0]] = res[1]
# Out:
# (None, 'zero-shot-prompting', 'RECORD_WISE', None) 0.5700000000000001

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "RECORD_WISE", embedding_method = "FIELD_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.9, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.8, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.7, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.6, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.5, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0
# (0.4, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.015037593984962407
# (0.3, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.4725274725274725
# (0.2, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.5700000000000001
# (0.1, 'both', 'RECORD_WISE', 'FIELD_SERIALIZED') 0.5700000000000001

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "RECORD_WISE", embedding_method = "FULL_SERIALIZED")
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0
# (0.9, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.5700000000000001
# (0.8, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.5700000000000001
# (0.7, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.5700000000000001
# (0.6, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.5700000000000001
# (0.5, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.5700000000000001
# (0.4, 'both', 'RECORD_WISE', 'FULL_SERIALIZED') 0.5700000000000001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 for t in thresholds:
# ----> 2     res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "RECORD_WISE", embedding_method = "FULL_SERIALIZED")
#       3     evaluation_results[res[0]] = res[1]
#       4     if res[1]["Recall"] == 1.0:
#
# Cell In[11], line 16, in evaluate(em, sv, threshold, method, embedding_comparison, embedding_method)
#       7 op = InnerSoftJoin(
#       8     op1, op2, em=em, sv=sv,
#       9     threshold=threshold, method=method,
#    (...)
#      12     embedding_method = embedding_method
#      13 )
#      15 tic = time.time()
# ---> 16 result = op.open().fetch_all()
#      17 toc = time.time()
#      18 pred = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for x in result}
#
# File ~/PycharmProjects/Master/db/operators/Operator.py:45, in Operator.fetch_all(self)
#      44 def fetch_all(self): # Interface for user to retrieve all records
# ---> 45     return list(self)
#
# File ~/PycharmProjects/Master/db/operators/Join.py:484, in InnerSoftJoin.__next__(self)
#     482 tic = time.time()
#     483 # entity matching not passing -> continue with next left record
# --> 484 result_em = self.sv(prompt, system_prompt=self.zs_system_prompt)
#     485 toc = time.time()
#     487 key = (frozenset(self.records_left[idx].items()), frozenset(self.record_right.items()))
#
# File ~/PycharmProjects/Master/models/semantic_validation/LLaMA.py:61, in LLaMAValidationModel.__call__(self, prompt, system_prompt)
#      58     prompt_tok = prompt_tok.cuda()
#      59     attention_mask = attention_mask.cuda()
# ---> 61 answer_tok = self._model.generate(prompt_tok, attention_mask = attention_mask, **self.generation_config)
#      62 answer = self._tokenizer.decode( answer_tok[0][len(prompt_tok[0]):], skip_special_tokens=True ).lower()
#      64 if answer not in ("yes", "no"):
#
# File ~/PycharmProjects/Master/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/PycharmProjects/Master/.venv/lib/python3.12/site-packages/transformers/generation/utils.py:2255, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2247     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2248         input_ids=input_ids,
#    2249         expand_size=generation_config.num_return_sequences,
#    2250         is_encoder_decoder=self.config.is_encoder_decoder,
#    2251         **model_kwargs,
#    2252     )
#    2254     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2255     result = self._sample(
#    2256         input_ids,
#    2257         logits_processor=prepared_logits_processor,
#    2258         stopping_criteria=prepared_stopping_criteria,
#    2259         generation_config=generation_config,
#    2260         synced_gpus=synced_gpus,
#    2261         streamer=streamer,
#    2262         **model_kwargs,
#    2263     )
#    2265 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2266     # 11. prepare beam search scorer
#    2267     beam_scorer = BeamSearchScorer(
#    2268         batch_size=batch_size,
#    2269         num_beams=generation_config.num_beams,
#    (...)
#    2274         max_length=generation_config.max_length,
#    2275     )
#
# KeyboardInterrupt:

# %%
for t in thresholds:
    res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "COLUMN_WISE", embedding_method = None)
    evaluation_results[res[0]] = res[1]
    if res[1]["Recall"] == 1.0:
        break
# Out:
# (1.0, 'both', 'COLUMN_WISE', None) 0
# (0.9, 'both', 'COLUMN_WISE', None) 0.4666666666666667
# (0.8, 'both', 'COLUMN_WISE', None) 0.5555555555555556
# (0.7, 'both', 'COLUMN_WISE', None) 0.5700000000000001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 for t in thresholds:
# ----> 2     res = evaluate(stem, lsv, threshold = t, method = "both", embedding_comparison = "COLUMN_WISE", embedding_method = None)
#       3     evaluation_results[res[0]] = res[1]
#       4     if res[1]["Recall"] == 1.0:
#
# Cell In[11], line 16, in evaluate(em, sv, threshold, method, embedding_comparison, embedding_method)
#       7 op = InnerSoftJoin(
#       8     op1, op2, em=em, sv=sv,
#       9     threshold=threshold, method=method,
#    (...)
#      12     embedding_method = embedding_method
#      13 )
#      15 tic = time.time()
# ---> 16 result = op.open().fetch_all()
#      17 toc = time.time()
#      18 pred = {tuple([x[f"left_{matches.columns[0]}"], x[f"right_{matches.columns[1]}"]]) for x in result}
#
# File ~/PycharmProjects/Master/db/operators/Operator.py:45, in Operator.fetch_all(self)
#      44 def fetch_all(self): # Interface for user to retrieve all records
# ---> 45     return list(self)
#
# File ~/PycharmProjects/Master/db/operators/Join.py:404, in InnerSoftJoin.__next__(self)
#     400 if self.embedding_comparison == "COLUMN_WISE":
#     401     # Embedd and compare the cosine similarities for all join columns separately
#     402     # If mean cosine similarity (for all join columns) > threshold -> consider as match
#     403     keys_right = [str(self.record_right[col.column_name]) for col in self.join_columns_right]
# --> 404     embs_right = self.em(keys_right)
#     406     indices_total = set()
#     407     for i, vi in enumerate(self.vector_indices):
#     408         # Perform range query on vector Stores for every column embedding
#     409         # noinspection PyArgumentList
#
# File ~/PycharmProjects/Master/models/embedding/Model.py:12, in EmbeddingModel.__call__(self, text, batch_size)
#      10 embeddings = []
#      11 for batch in range(0, len(text), batch_size):
# ---> 12     embeddings.append(self.embedd(text[batch : batch + batch_size]))
#      14 return np.concatenate(embeddings)
#
# File ~/PycharmProjects/Master/models/embedding/SentenceTransformer.py:21, in SentenceTransformerEmbeddingModel.embedd(self, text)
#      20 def embedd(self, text: str | list[str]) -> np.array:
# ---> 21     self.model_to_cuda()
#      23     tokens = self._tokenizer(text, padding=True, truncation=True, return_tensors='pt')
#      25     if torch.cuda.is_available():
#
# File ~/PycharmProjects/Master/models/__init__.py:40, in Model.model_to_cuda(self)
#      38 def model_to_cuda(self):
#      39     if torch.cuda.is_available():
# ---> 40         self._model_mgr.get_gpu_resources(self)
#      41         self._model.cuda()
#
# File ~/PycharmProjects/Master/models/__init__.py:22, in ModelMgr.get_gpu_resources(self, model)
#      20     self.current_model_gpu = model
#      21 elif self.current_model_gpu != model:
# ---> 22     self.current_model_gpu.model_to_cpu()
#      23     self.current_model_gpu = model
#      24 else:
#
# File ~/PycharmProjects/Master/models/__init__.py:36, in Model.model_to_cpu(self)
#      35 def model_to_cpu(self):
# ---> 36     self._model.cpu()
#
# File ~/PycharmProjects/Master/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1118, in Module.cpu(self)
#    1109 def cpu(self: T) -> T:
#    1110     r"""Move all model parameters and buffers to the CPU.
#    1111
#    1112     .. note::
#    (...)
#    1116         Module: self
#    1117     """
# -> 1118     return self._apply(lambda t: t.cpu())
#
# File ~/PycharmProjects/Master/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:900, in Module._apply(self, fn, recurse)
#     898 if recurse:
#     899     for module in self.children():
# --> 900         module._apply(fn)
#     902 def compute_should_use_set_data(tensor, tensor_applied):
#     903     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     904         # If the new tensor has compatible tensor type as the existing tensor,
#     905         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     910         # global flag to let the user control whether they want the future
#     911         # behavior of overwriting the existing tensor or not.
#
# File ~/PycharmProjects/Master/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:900, in Module._apply(self, fn, recurse)
#     898 if recurse:
#     899     for module in self.children():
# --> 900         module._apply(fn)
#     902 def compute_should_use_set_data(tensor, tensor_applied):
#     903     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     904         # If the new tensor has compatible tensor type as the existing tensor,
#     905         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     910         # global flag to let the user control whether they want the future
#     911         # behavior of overwriting the existing tensor or not.
#
# File ~/PycharmProjects/Master/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:927, in Module._apply(self, fn, recurse)
#     923 # Tensors stored in modules are graph leaves, and we don't want to
#     924 # track autograd history of `param_applied`, so we have to use
#     925 # `with torch.no_grad():`
#     926 with torch.no_grad():
# --> 927     param_applied = fn(param)
#     928 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     930 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~/PycharmProjects/Master/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1118, in Module.cpu.<locals>.<lambda>(t)
#    1109 def cpu(self: T) -> T:
#    1110     r"""Move all model parameters and buffers to the CPU.
#    1111
#    1112     .. note::
#    (...)
#    1116         Module: self
#    1117     """
# -> 1118     return self._apply(lambda t: t.cpu())
#
# KeyboardInterrupt:

# %%
gt_blue = {tuple(row[col] for col in list(left.columns) + list(right.columns)) for _, row in candidates.iterrows()}

for key in tqdm.tqdm(evaluation_results):
    result = pd.DataFrame(evaluation_results[key]["pred"], columns=["l", "r"])\
        .merge(left, left_on="l", right_on="left_snoLeft")\
        .merge(right, left_on="r", right_on="right_snoRight")

    pred_blue = {tuple(row[col] for col in list(left.columns) + list(right.columns)) for _, row in result.iterrows()}
    scores_bleu = calc_bleu(gt_blue, pred_blue)
    for score_bleu in scores_bleu:
        evaluation_results[key][score_bleu] = scores_bleu[score_bleu]
# Out:
# 100%|██████████| 38/38 [02:21<00:00,  3.71s/it]

# %%
keys = ["threshold", "method", "embedding_comparison", "embedding_method"]
evaluation_results_list = [v | {ki: vi for ki, vi in zip(keys, k)} for k, v in evaluation_results.items()]
df_evaluation_results = pd.DataFrame.from_records(evaluation_results_list, index=keys).drop(columns=["pred"])
df_evaluation_results
# Out:
#                                                                      Precision  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED   1.000000
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED   0.691176
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED   0.011893
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED    0.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED    0.608911
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED    0.010417
# 1.0       threshold           COLUMN_WISE          NaN                0.000000
# 0.9       threshold           COLUMN_WISE          NaN                0.875000
# 0.8       threshold           COLUMN_WISE          NaN                0.818792
# 0.7       threshold           COLUMN_WISE          NaN                0.702128
# NaN       zero-shot-prompting RECORD_WISE          NaN                0.838235
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED   0.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED   1.000000
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED   0.860000
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED   0.838235
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED   0.838235
# 1.0       both                RECORD_WISE          FULL_SERIALIZED    0.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED    0.838235
# 0.8       both                RECORD_WISE          FULL_SERIALIZED    0.838235
# 0.7       both                RECORD_WISE          FULL_SERIALIZED    0.838235
# 0.6       both                RECORD_WISE          FULL_SERIALIZED    0.838235
# 0.5       both                RECORD_WISE          FULL_SERIALIZED    0.838235
# 0.4       both                RECORD_WISE          FULL_SERIALIZED    0.838235
# 1.0       both                COLUMN_WISE          NaN                0.000000
# 0.9       both                COLUMN_WISE          NaN                0.875000
# 0.8       both                COLUMN_WISE          NaN                0.833333
# 0.7       both                COLUMN_WISE          NaN                0.838235
#
#                                                                        Recall  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.007576
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.712121
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.931818
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN               0.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.477273
# 0.8       threshold           COLUMN_WISE          NaN               0.924242
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.431818
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.007576
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.325758
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.431818
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.431818
# 1.0       both                RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.431818
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.431818
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.431818
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.431818
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.431818
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   0.431818
# 1.0       both                COLUMN_WISE          NaN               0.000000
# 0.9       both                COLUMN_WISE          NaN               0.318182
# 0.8       both                COLUMN_WISE          NaN               0.416667
# 0.7       both                COLUMN_WISE          NaN               0.431818
#
#                                                                      F1 Score  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.015038
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.701493
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  0.023506
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.736527
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   0.020619
# 1.0       threshold           COLUMN_WISE          NaN               0.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.617647
# 0.8       threshold           COLUMN_WISE          NaN               0.868327
# 0.7       threshold           COLUMN_WISE          NaN               0.825000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.570000
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED  0.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.015038
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.472527
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.570000
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.570000
# 1.0       both                RECORD_WISE          FULL_SERIALIZED   0.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.570000
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.570000
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.570000
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.570000
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.570000
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   0.570000
# 1.0       both                COLUMN_WISE          NaN               0.000000
# 0.9       both                COLUMN_WISE          NaN               0.466667
# 0.8       both                COLUMN_WISE          NaN               0.555556
# 0.7       both                COLUMN_WISE          NaN               0.570000
#
#                                                                       tp   fn  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED    1  131
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED   94   38
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  132    0
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED     0  132
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   123    9
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   132    0
# 1.0       threshold           COLUMN_WISE          NaN                 0  132
# 0.9       threshold           COLUMN_WISE          NaN                63   69
# 0.8       threshold           COLUMN_WISE          NaN               122   10
# 0.7       threshold           COLUMN_WISE          NaN               132    0
# NaN       zero-shot-prompting RECORD_WISE          NaN                57   75
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED    0  132
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED    1  131
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED   43   89
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED   57   75
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED   57   75
# 1.0       both                RECORD_WISE          FULL_SERIALIZED     0  132
# 0.9       both                RECORD_WISE          FULL_SERIALIZED    57   75
# 0.8       both                RECORD_WISE          FULL_SERIALIZED    57   75
# 0.7       both                RECORD_WISE          FULL_SERIALIZED    57   75
# 0.6       both                RECORD_WISE          FULL_SERIALIZED    57   75
# 0.5       both                RECORD_WISE          FULL_SERIALIZED    57   75
# 0.4       both                RECORD_WISE          FULL_SERIALIZED    57   75
# 1.0       both                COLUMN_WISE          NaN                 0  132
# 0.9       both                COLUMN_WISE          NaN                42   90
# 0.8       both                COLUMN_WISE          NaN                55   77
# 0.7       both                COLUMN_WISE          NaN                57   75
#
#                                                                         fp  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED      0
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED     42
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  10967
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED       0
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED      79
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   12540
# 1.0       threshold           COLUMN_WISE          NaN                   0
# 0.9       threshold           COLUMN_WISE          NaN                   9
# 0.8       threshold           COLUMN_WISE          NaN                  27
# 0.7       threshold           COLUMN_WISE          NaN                  56
# NaN       zero-shot-prompting RECORD_WISE          NaN                  11
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED      0
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED      7
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED     11
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED     11
# 1.0       both                RECORD_WISE          FULL_SERIALIZED       0
# 0.9       both                RECORD_WISE          FULL_SERIALIZED      11
# 0.8       both                RECORD_WISE          FULL_SERIALIZED      11
# 0.7       both                RECORD_WISE          FULL_SERIALIZED      11
# 0.6       both                RECORD_WISE          FULL_SERIALIZED      11
# 0.5       both                RECORD_WISE          FULL_SERIALIZED      11
# 0.4       both                RECORD_WISE          FULL_SERIALIZED      11
# 1.0       both                COLUMN_WISE          NaN                   0
# 0.9       both                COLUMN_WISE          NaN                   6
# 0.8       both                COLUMN_WISE          NaN                  11
# 0.7       both                COLUMN_WISE          NaN                  11
#
#                                                                         runtime  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED    0.784642
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED    0.517723
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED    0.558190
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED    0.459369
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED    0.531677
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED    0.519573
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED    0.479295
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED    0.541726
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED    0.541097
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED     0.613195
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED     0.892786
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED     0.661544
# 1.0       threshold           COLUMN_WISE          NaN                 1.262030
# 0.9       threshold           COLUMN_WISE          NaN                 0.983028
# 0.8       threshold           COLUMN_WISE          NaN                 1.300264
# 0.7       threshold           COLUMN_WISE          NaN                 1.354308
# NaN       zero-shot-prompting RECORD_WISE          NaN               443.753981
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED    2.344728
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED    0.552756
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED    0.519184
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED    0.534711
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED    0.556190
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED    0.590647
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED    2.715976
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  161.004560
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  515.230535
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  646.283259
# 1.0       both                RECORD_WISE          FULL_SERIALIZED     1.798898
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   170.327684
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   475.306665
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   568.696897
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   559.643228
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   557.860414
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   557.424434
# 1.0       both                COLUMN_WISE          NaN                 1.569989
# 0.9       both                COLUMN_WISE          NaN                60.792521
# 0.8       both                COLUMN_WISE          NaN               118.868977
# 0.7       both                COLUMN_WISE          NaN               128.741153
#
#                                                                         bleu1  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.351403
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.883405
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.981024
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.768695
# 0.8       threshold           COLUMN_WISE          NaN               0.972785
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.756380
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.351403
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.696685
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.756380
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.756380
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.756380
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.756380
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.756380
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.756380
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.756380
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   0.756380
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN               0.685948
# 0.8       both                COLUMN_WISE          NaN               0.750892
# 0.7       both                COLUMN_WISE          NaN               0.756380
#
#                                                                         bleu2  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.215811
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.851309
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.975707
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.709853
# 0.8       threshold           COLUMN_WISE          NaN               0.964269
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.689761
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.215811
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.612935
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.689761
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.689761
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.689761
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.689761
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.689761
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.689761
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.689761
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   0.689761
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN               0.603039
# 0.8       both                COLUMN_WISE          NaN               0.682502
# 0.7       both                COLUMN_WISE          NaN               0.689761
#
#                                                                         bleu3  \
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.157853
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.832391
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.972209
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.672419
# 0.8       threshold           COLUMN_WISE          NaN               0.958860
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.647774
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.157853
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.563038
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.647774
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.647774
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.647774
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.647774
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.647774
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.647774
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.647774
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   0.647774
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN               0.552154
# 0.8       both                COLUMN_WISE          NaN               0.639200
# 0.7       both                COLUMN_WISE          NaN               0.647774
#
#                                                                         bleu4
# threshold method              embedding_comparison embedding_method
# 1.0       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       threshold           RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       threshold           RECORD_WISE          FIELD_SERIALIZED  0.118150
# 0.3       threshold           RECORD_WISE          FIELD_SERIALIZED  0.817656
# 0.2       threshold           RECORD_WISE          FIELD_SERIALIZED  1.000000
# 1.0       threshold           RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       threshold           RECORD_WISE          FULL_SERIALIZED   0.969507
# 0.8       threshold           RECORD_WISE          FULL_SERIALIZED   1.000000
# 1.0       threshold           COLUMN_WISE          NaN              -1.000000
# 0.9       threshold           COLUMN_WISE          NaN               0.643116
# 0.8       threshold           COLUMN_WISE          NaN               0.954607
# 0.7       threshold           COLUMN_WISE          NaN               1.000000
# NaN       zero-shot-prompting RECORD_WISE          NaN               0.614285
# 1.0       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.9       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.8       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.7       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.6       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.5       both                RECORD_WISE          FIELD_SERIALIZED -1.000000
# 0.4       both                RECORD_WISE          FIELD_SERIALIZED  0.118150
# 0.3       both                RECORD_WISE          FIELD_SERIALIZED  0.524751
# 0.2       both                RECORD_WISE          FIELD_SERIALIZED  0.614285
# 0.1       both                RECORD_WISE          FIELD_SERIALIZED  0.614285
# 1.0       both                RECORD_WISE          FULL_SERIALIZED  -1.000000
# 0.9       both                RECORD_WISE          FULL_SERIALIZED   0.614285
# 0.8       both                RECORD_WISE          FULL_SERIALIZED   0.614285
# 0.7       both                RECORD_WISE          FULL_SERIALIZED   0.614285
# 0.6       both                RECORD_WISE          FULL_SERIALIZED   0.614285
# 0.5       both                RECORD_WISE          FULL_SERIALIZED   0.614285
# 0.4       both                RECORD_WISE          FULL_SERIALIZED   0.614285
# 1.0       both                COLUMN_WISE          NaN              -1.000000
# 0.9       both                COLUMN_WISE          NaN               0.512976
# 0.8       both                COLUMN_WISE          NaN               0.604713
# 0.7       both                COLUMN_WISE          NaN               0.614285

# %%
df_evaluation_results.to_csv(f"results/iTunesAmazon_{stem}_{lsv}.csv")
